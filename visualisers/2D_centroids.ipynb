# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path: sys.path.append(module_path)
from pathlib import Path

from SlicePlotting import Plotter

# %%
# %matplotlib notebook

# %%
annotation_path = Path.home()/'code'/'allen-data-mining'/'connectivity'/'mouse_connectivity'/'annotation'/'ccf_2017'/'annotation_10.nrrd'
data_path = Path.home()/'Desktop'/'data'/'connectivity'

# %%
plotter = Plotter(annotation_path, data_path)
# Out:
# Allen Mouse Connectivity library loaded.
# Annotation volume with shape (1320, 800, 1140) loaded.

# %%
parameters = {
    'area': 'VISam',
    'projection_metric': 'normalized_projection_volume',
    'hemisphere_id': 2,
    'projection_type': 'ipsilateral',
    'injection_volume_threshold': 0.01,
    'projection_volume_threshold': 0.1
}
plotter.load_parameters(parameters)
# Out:
# Parameters loaded:
# {'area': 'VISam', 'projection_metric': 'normalized_projection_volume', 'hemisphere_id': 2, 'projection_type': 'ipsilateral', 'injection_volume_threshold': 0.01, 'projection_volume_threshold': 0.1}
# Centroids data loaded from ipsilateral_centroids_dict_hem_2_inj_vol_thresh_0.01_target_vol_thresh_0.1_VISam.pkl

# %%
plotter.plot()

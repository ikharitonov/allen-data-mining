# %% [markdown]
# # Receptor Density - Gene Expression Data
#
#
# General API guide: http://help.brain-map.org/display/mousebrain/API
#
# General RMA Guide http://help.brain-map.org/pages/viewpage.action?pageId=5308449
#
# Class Hierarchy http://api.brain-map.org/class_hierarchy
#
# Examples RMA URL Queries http://help.brain-map.org/display/api/Example+Queries+for+Experiment+Metadata
#
# Python API Queries https://alleninstitute.github.io/AllenSDK/data_api_client.html
#
# RMA Query Building Web Application http://api.brain-map.org/examples/rma_builder/index.html

# %% [markdown]
# ### Informatics Data Processing
# The informatics data processing pipeline produces results that enable the navigation, analysis and visualization. The pipeline consists of the following components:
# - an annotated 3-D reference space,
# - an alignment module,
# - an expression detection module,
# - an expression gridding module, and
# - a structure unionizer module.
#
# The output of the pipeline is quantified expression values at a grid voxel level and at a structure level according to the integrated reference atlas ontology. The grid level data are used downstream to provide a differential and correlative gene search service and to support visualization of spatial relationships.

# %%
from allensdk.api.queries.rma_api import RmaApi
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

rma = RmaApi()

# %% [markdown]
# Get experiments for a particular gene - DRD1

# %%
# http://api.brain-map.org/api/v2/data/query.xml?criteria=
# model::SectionDataSet
# ,
# rma::criteria,
# products[abbreviation$eqMouse],genes[acronym$eqDrd1]
# ,
# rma::include,
# structure_unionizes

gene = "Drd1"
        
data = rma.model_query('SectionDataSet', criteria="products[abbreviation$eq'Mouse'],genes[acronym$eq'"+gene+"']",
                      include="structure_unionizes")

# %%
data_df = pd.DataFrame(data)
data_df
# Out:
#   blue_channel delegate expression failed  failed_facet green_channel  \
# 0         None     True       True  False     734881840          None
# 1         None    False      False  False     734881840          None
# 2         None    False      False  False     734881840          None
# 3         None    False      False  False     734881840          None
#
#          id  name  plane_of_section_id               qc_date red_channel  \
# 0  71307280  None                    2  2009-05-02T22:56:37Z        None
# 1       352  None                    1                  None        None
# 2       353  None                    2                  None        None
# 3       354  None                    2                  None        None
#
#    reference_space_id rnaseq_design_id  section_thickness  specimen_id  \
# 0                  10             None               25.0     70429761
# 1                   9             None               25.0       702565
# 2                  10             None               25.0       702529
# 3                  10             None               25.0       702473
#
#    sphinx_id                                  storage_directory  \
# 0     150678  /external/aibssan/production32/prod334/image_s...
# 1      78451            /external/mouse/prod1/image_series_352/
# 2      76510            /external/mouse/prod1/image_series_353/
# 3      95220            /external/mouse/prod0/image_series_354/
#
#                                  structure_unionizes  weight
# 0  [{'expression_density': 0.0159272, 'expression...    5470
# 1  [{'expression_density': 0.0136562, 'expression...    5470
# 2  [{'expression_density': 0.00817143, 'expressio...    5470
# 3  [{'expression_density': 7.11597e-05, 'expressi...    5270

# %%
experiment_id = 353
param = 'expression_density'

# %%
exp_union_data = pd.DataFrame(data_df[data_df['id']==experiment_id]['structure_unionizes'].item())
exp_union_data
# Out:
#       expression_density  expression_energy         id  section_data_set_id  \
# 0               0.008171           1.097120  398484594                  353
# 1               0.008171           1.097120  398484597                  353
# 2               0.010952           1.481770  398484604                  353
# 3               0.012336           1.672050  398484612                  353
# 4               0.000695           0.087989  398484614                  353
# 5               0.001059           0.145861  398484620                  353
# Out:
# 205
# 205
# 211    0.07296
# Name: expression_density, dtype: float64

# %%
# printing structure name, id and expression density for all unionized data points

# for s_id in newdf['structure_id'].unique():
#     structure = rma.model_query('StructureLookup', criteria="structure[id$eq"+str(s_id)+"]",include="structure")[0]
#     print(structure['structure']['name'],'--',structure['structure']['acronym'],'--','id',s_id,'--',param,'=',newdf[newdf['structure_id']==s_id][param].item())
# Out:
# forebrain -- F -- id 15566 -- expression_density = 0.0109517
# secondary prosencephalon -- SP -- id 15567 -- expression_density = 0.0123361
# caudal secondary prosencephalon -- CSP -- id 15738 -- expression_density = 0.0128722
# telencephalic vesicle -- Tel -- id 15739 -- expression_density = 0.0131925
# roof plate of evaginated telencephalic vesicle -- TelR -- id 15740 -- expression_density = 0.0127002
# alar plate of evaginated telencephalic vesicle -- TelA -- id 15750 -- expression_density = 0.0131926
# subpallium -- SPall -- id 15751 -- expression_density = 0.0416834
# paraseptal subpallium -- PaSe -- id 15784 -- expression_density = 0.0290781
# septodiagonal transition area -- SeDg -- id 15785 -- expression_density = 0.0192151
# mantle zone of SeDg -- SeDgm -- id 15787 -- expression_density = 0.0192151
# intermediate stratum of SeDg -- SeDgi -- id 15792 -- expression_density = 0.0269407
# substantia innominata/basal nucleus, transitional part -- SIBT -- id 15793 -- expression_density = 0.0278855
# septopallidal transition area -- SePal -- id 15797 -- expression_density = 0.0388467
# mantle zone of SePal -- SePalm -- id 15799 -- expression_density = 0.0388467
# intermediate stratum of SePal -- SePali -- id 15803 -- expression_density = 0.0537056
# septopallidal core nucleus -- SePalCo -- id 15804 -- expression_density = 0.0497457
# septopallidal shell area -- SePalSh -- id 15805 -- expression_density = 0.0596453
# superficial stratum of SePal -- SePals -- id 15806 -- expression_density = 0.0179515
# septopallidal part of the olfactory tuberculum -- TuSePal -- id 15807 -- expression_density = 0.0170277
# island of Calleja major -- ICjM -- id 15808 -- expression_density = 0.0268814
# septostriatal transition area (accumbens) -- SeStr -- id 15809 -- expression_density = 0.0291792
# mantle zone of SeStr -- SeStrm -- id 15811 -- expression_density = 0.0291792
# periventricular stratum of SeStr -- SeStrp -- id 15812 -- expression_density = 0.0334994
# accumbens nucleus, core domain -- AcbCo -- id 15813 -- expression_density = 0.0334994
# intermediate stratum of SeStr -- SeStri -- id 15814 -- expression_density = 0.0258341
# accumbens nucleus, shell domain -- AcbSh -- id 15815 -- expression_density = 0.0258341
# superficial stratum of SeStr -- SeStrs -- id 15816 -- expression_density = 0.0238267
# septostriatal part of the olfactory tuberculum -- TuSeStr -- id 15817 -- expression_density = 0.0238267
# central subpallium (classic basal ganglia) -- CSPall -- id 15818 -- expression_density = 0.0523684
# superficial stratum of Dg -- Dgs -- id 15831 -- expression_density = 0.0223008
# horizontal nucleus of the diagonal band -- HDB -- id 15832 -- expression_density = 0.0243512
# pallidum (globus pallidus complex) -- Pal -- id 15834 -- expression_density = 0.0312047
# mantle zone of Pal -- Palm -- id 15836 -- expression_density = 0.0312047
# periventricular stratum of Pal -- Palp -- id 15837 -- expression_density = 0.0227192
# bed nucleus of the stria terminalis, laterocentral division -- BSTLC -- id 15838 -- expression_density = 0.0227192
# intermediate stratum of Pal -- Pali -- id 15842 -- expression_density = 0.0263643
# external globus pallidum -- EPal -- id 15843 -- expression_density = 0.0307317
# ventral pallidum -- VPal -- id 15844 -- expression_density = 0.0140508
# superficial stratum of Pal -- Pals -- id 15845 -- expression_density = 0.0438185
# pallidal part of olfactory tuberculum -- TuPal -- id 15846 -- expression_density = 0.0435757
# plexiform layer of TuPal -- TuPal1 -- id 15847 -- expression_density = 0.0270059
# corticoid layer of TuPal -- TuPal2 -- id 15848 -- expression_density = 0.0396154
# polymorph layer of TuPal -- TuPal3 -- id 15849 -- expression_density = 0.0575873
# pallidal islands of Calleja -- ICjPal -- id 15850 -- expression_density = 0.0729601
# striatum (corpus striatum) -- Str -- id 15851 -- expression_density = 0.0684217
# mantle zone of Str -- Strm -- id 15853 -- expression_density = 0.0684217
# periventricular stratum of Str -- Strp -- id 15854 -- expression_density = 0.0533908
# caudate nucleus -- Cau -- id 15855 -- expression_density = 0.0533908
# intermediate stratum of Str -- Stri -- id 15856 -- expression_density = 0.0743426
# putamen -- Put -- id 15857 -- expression_density = 0.07817
# ventral striatum -- VStr -- id 15858 -- expression_density = 0.0501497
# laterostriatal stripe -- LSS -- id 15860 -- expression_density = 0.0712876
# superficial stratum of Str -- Strs -- id 15861 -- expression_density = 0.0463255
# striatal part of olfactory tuberculum -- TuStr -- id 15862 -- expression_density = 0.0471066
# plexiform layer of TuStr -- TuStr1 -- id 15863 -- expression_density = 0.0308942
# corticoid layer of TuStr -- TuStr2 -- id 15864 -- expression_density = 0.047209
# polymorph layer of TuStr -- TuStr3 -- id 15865 -- expression_density = 0.0603912
# subpallial amygdala -- ASPall -- id 15867 -- expression_density = 0.0112146
# striatal amygdala -- AStr -- id 15868 -- expression_density = 0.0143113
# mantle zone of AStr -- AStrm -- id 15870 -- expression_density = 0.0143113
# periventricular stratum of AStr -- AStrp -- id 15871 -- expression_density = 0.0239814
# amygdalo-striatal transition -- ASt -- id 15872 -- expression_density = 0.0239814
# central amygdalar nucleus, capsular part -- CeC -- id 15875 -- expression_density = 0.010957
# pallidal amygdala -- APal -- id 15878 -- expression_density = 0.0171891
# mantle zone of APal -- APalm -- id 15880 -- expression_density = 0.0171891
# periventricular stratum of APal -- APalp -- id 15881 -- expression_density = 0.0197422
# bed nucleus of stria terminalis, lateral amygdaloid division -- BSTLA -- id 15882 -- expression_density = 0.0197422
# ventropallial prepiriform area -- VPrP -- id 15928 -- expression_density = 0.0252669
# mantle zone of VPrP -- VPrPm -- id 15930 -- expression_density = 0.0252669
# intermediate stratum of VPrP -- VPrPi -- id 15932 -- expression_density = 0.0377804
# bed nucleus of the external capsule -- BEC -- id 15933 -- expression_density = 0.075864
# dorsal endopiriform nucleus -- DEn -- id 15934 -- expression_density = 0.0313918
# ventral endopiriform nucleus -- VEn -- id 15935 -- expression_density = 0.0195726
# superficial stratum of VPrP -- VPrPs -- id 15936 -- expression_density = 0.0198419
# layer 1 of VPrP cortex -- VPrP1 -- id 15937 -- expression_density = 0.0221063
# layer 2 of VPrP cortex -- VPrP2 -- id 15938 -- expression_density = 0.0196395
# layer 3 of VPrP cortex -- VPrP3 -- id 15939 -- expression_density = 0.0151405
# lateral amygdaloid nucleus -- La -- id 15944 -- expression_density = 0.01284
# lateral pallium -- LPall -- id 15956 -- expression_density = 0.0158913
# lateropallial prepiriform area -- LPrP -- id 15979 -- expression_density = 0.0273661
# mantle zone of LPrP -- LPrPm -- id 15981 -- expression_density = 0.0273661
# intermediate stratum of LPrP -- LPrPi -- id 15983 -- expression_density = 0.074014
# claustrum -- Cl -- id 15984 -- expression_density = 0.074014
# superficial stratum of LPrP -- LPrPs -- id 15985 -- expression_density = 0.0114741
# layer 2 of LPrP cortex -- LPrP2 -- id 15987 -- expression_density = 0.0171057
# layer 3 of LPrP cortex -- LPrP3 -- id 15988 -- expression_density = 0.0127535
# layer 6 of FCx -- FC-6 -- id 16013 -- expression_density = 0.025466
# sublayer 6a of FCx -- FC-6a -- id 16014 -- expression_density = 0.0234757
# sublayer 6b of FCx -- FC-6b -- id 16015 -- expression_density = 0.034439
# layer 6 of PCx -- PC-6 -- id 16027 -- expression_density = 0.0116368
# insular cortex -- InsCx -- id 16058 -- expression_density = 0.0334331
# mantle zone of InsCx -- InsCm -- id 16060 -- expression_density = 0.0334331
# superficial stratum of InsCx (cortical plate/marginal zone) -- InsCs -- id 16063 -- expression_density = 0.0334331
# layer 2 of InsCx -- InsC-2 -- id 16065 -- expression_density = 0.0170922
# layer 3 of InsCx -- InsC-3 -- id 16066 -- expression_density = 0.0305432
# layer 4 of InsCx -- InsC-4 -- id 16067 -- expression_density = 0.014249
# layer 5 of InsCx -- InsC-5 -- id 16068 -- expression_density = 0.0438288
# layer 6 of InsCx -- InsC-6 -- id 16069 -- expression_density = 0.0656888
# sublayer 6a of InsCx -- InsC-6a -- id 16070 -- expression_density = 0.0896456
# sublayer 6b of InsCx -- InsC-6b -- id 16071 -- expression_density = 0.0813468
# retrosplenial cortex -- RSCx -- id 16093 -- expression_density = 0.0130956
# layer 2 of RSC -- RSC-2 -- id 16095 -- expression_density = 0.016864
# layer 3 of RSC -- RSC-3 -- id 16096 -- expression_density = 0.0220883
# layer 5 of RSC -- RSC-5 -- id 16098 -- expression_density = 0.0147462
# nucleus of Barrington -- Bar -- id 16973 -- expression_density = 0.0105354
# r5 (gustatory) part of solitary complex -- r5Sol -- id 17240 -- expression_density = 0.0101931
# r7 part of the dorsal cochlear nucleus -- r7DC -- id 17359 -- expression_density = 0.0136433
# periventricular stratum of r5Tr -- r5Trp -- id 111220758 -- expression_density = 0.0101931
# periventricular stratum of r7Co -- r7Cop -- id 111220810 -- expression_density = 0.0136433
# Primary somatosensory area, mouth, layer 6b -- SSp-m6b -- id 2 -- expression_density = 0.0925622
# Superior colliculus, motor related, deep white layer -- SCdw -- id 42 -- expression_density = 0.0160578
# Nucleus accumbens -- ACB -- id 56 -- expression_density = 0.0549571
# Entorhinal area, lateral part, layer 6b -- ENTl6b -- id 60 -- expression_density = 0.0126448
# Agranular insular area -- AI -- id 95 -- expression_density = 0.0347523
# Agranular insular area, dorsal part -- AId -- id 104 -- expression_density = 0.0226871
# Agranular insular area, posterior part -- AIp -- id 111 -- expression_density = 0.0239225
# Agranular insular area, ventral part -- AIv -- id 119 -- expression_density = 0.0634438
# Gustatory areas, layer 4 -- GU4 -- id 148 -- expression_density = 0.0114451
# Gustatory areas, layer 5 -- GU5 -- id 187 -- expression_density = 0.0495735
# Dorsal auditory area, layer 6b -- AUDd6b -- id 243 -- expression_density = 0.0105933
# Auditory areas -- AUD -- id 247 -- expression_density = 0.0127369
# Piriform area, molecular layer -- PIR1 -- id 276 -- expression_density = 0.0113908
# Piriform area, pyramidal layer -- PIR2 -- id 284 -- expression_density = 0.0143028
# Piriform area, polymorph layer -- PIR3 -- id 291 -- expression_density = 0.0169551
# Magnocellular nucleus -- MA -- id 298 -- expression_density = 0.0230447
# Agranular insular area, posterior part, layer 6a -- AIp6a -- id 314 -- expression_density = 0.048404
# Primary somatosensory area -- SSp -- id 322 -- expression_density = 0.0103934
# Agranular insular area, dorsal part, layer 2/3 -- AId2/3 -- id 328 -- expression_density = 0.01631
# Perirhinal area, layer 6a -- PERI6a -- id 335 -- expression_density = 0.0645036
# Substantia innominata -- SI -- id 342 -- expression_density = 0.0228184
# Agranular insular area, posterior part, layer 5 -- AIp5 -- id 344 -- expression_density = 0.02526
# Primary somatosensory area, mouth -- SSp-m -- id 345 -- expression_density = 0.0175914
# Primary somatosensory area, nose -- SSp-n -- id 353 -- expression_density = 0.0224542
# Bed nuclei of the stria terminalis, anterior division -- BSTa -- id 359 -- expression_density = 0.0131191
# Primary somatosensory area, upper limb -- SSp-ul -- id 369 -- expression_density = 0.0150777
# Supplemental somatosensory area -- SSs -- id 378 -- expression_density = 0.0311529
# Orbital area, lateral part, layer 2/3 -- ORBl2/3 -- id 412 -- expression_density = 0.0192613
# Somatosensory areas -- SS -- id 453 -- expression_density = 0.0119014
# Olfactory tubercle, molecular layer -- OT1 -- id 458 -- expression_density = 0.027211
# Olfactory tubercle, pyramidal layer -- OT2 -- id 465 -- expression_density = 0.043628
# Olfactory tubercle, polymorph layer -- OT3 -- id 473 -- expression_density = 0.0508568
# Striatum -- STR -- id 477 -- expression_density = 0.0485418
# Islands of Calleja -- isl -- id 481 -- expression_density = 0.0331396
# Striatum dorsal region -- STRd -- id 485 -- expression_density = 0.0686528
# Major island of Calleja -- islm -- id 489 -- expression_density = 0.0291758
# Striatum ventral region -- STRv -- id 493 -- expression_density = 0.045062
# Bed nuclei of the stria terminalis, anterior division, anteromedial area -- BSTam -- id 498 -- expression_density = 0.0164115
# posteromedial visual area, layer 4 -- VISpm4 -- id 501 -- expression_density = 0.0108564
# Primary somatosensory area, lower limb, layer 6b -- SSp-ll6b -- id 510 -- expression_density = 0.0169761
# Bed nuclei of the stria terminalis, anterior division, fusiform nucleus -- BSTfu -- id 513 -- expression_density = 0.0119537
# Ventral auditory area, layer 6a -- AUDv6a -- id 520 -- expression_density = 0.0272739
# Bed nuclei of the stria terminalis, anterior division, anterolateral area -- BSTal -- id 537 -- expression_density = 0.013906
# Bed nuclei of the stria terminalis, anterior division, oval nucleus -- BSTov -- id 554 -- expression_density = 0.0291449
# Cerebrum -- CH -- id 567 -- expression_density = 0.013424
# Claustrum -- CLA -- id 583 -- expression_density = 0.0851319
# Diagonal band nucleus -- NDB -- id 596 -- expression_density = 0.0108963
# Ventral auditory area, layer 6b -- AUDv6b -- id 598 -- expression_density = 0.0635903
# Bed nuclei of the stria terminalis, posterior division, strial extension -- BSTse -- id 602 -- expression_density = 0.0282072
# Cerebral nuclei -- CNU -- id 623 -- expression_density = 0.0414182
# Primary somatosensory area, upper limb, layer 5 -- SSp-ul5 -- id 625 -- expression_density = 0.0131766
# Orbital area, lateral part, layer 5 -- ORBl5 -- id 630 -- expression_density = 0.0139122
# Gustatory areas, layer 6a -- GU6a -- id 638 -- expression_density = 0.0671904
# Gustatory areas, layer 6b -- GU6b -- id 662 -- expression_density = 0.0808043
# Caudoputamen -- CP -- id 672 -- expression_density = 0.0686528
# Agranular insular area, ventral part, layer 6a -- AIv6a -- id 675 -- expression_density = 0.0758159
# Visceral area -- VISC -- id 677 -- expression_density = 0.0450847
# Agranular insular area, ventral part, layer 2/3 -- AIv2/3 -- id 694 -- expression_density = 0.051494
# Primary somatosensory area, nose, layer 5 -- SSp-n5 -- id 702 -- expression_density = 0.0177652
# Cortical subplate -- CTXsp -- id 703 -- expression_density = 0.0280564
# Orbital area, lateral part -- ORBl -- id 723 -- expression_density = 0.0146945
# Olfactory tubercle -- OT -- id 754 -- expression_density = 0.0376712
# Agranular insular area, dorsal part, layer 6a -- AId6a -- id 783 -- expression_density = 0.0664734
# Temporal association areas, layer 6b -- TEa6b -- id 786 -- expression_density = 0.0599154
# Agranular insular area, ventral part, layer 5 -- AIv5 -- id 800 -- expression_density = 0.101075
# Pallidum -- PAL -- id 803 -- expression_density = 0.0117918
# Pallidum, ventral region -- PALv -- id 835 -- expression_density = 0.0228369
# Visceral area, layer 6b -- VISC6b -- id 849 -- expression_density = 0.0910803
# Visceral area, layer 6a -- VISC6a -- id 857 -- expression_density = 0.0553652
# Supplemental somatosensory area, layer 6a -- SSs6a -- id 862 -- expression_density = 0.0369955
# Primary somatosensory area, nose, layer 6a -- SSp-n6a -- id 889 -- expression_density = 0.0748341
# Supplemental somatosensory area, layer 6b -- SSs6b -- id 893 -- expression_density = 0.0749089
# External cuneate nucleus -- ECU -- id 903 -- expression_density = 0.0100543
# Perirhinal area -- PERI -- id 922 -- expression_density = 0.0645036
# Primary somatosensory area, nose, layer 6b -- SSp-n6b -- id 929 -- expression_density = 0.0986978
# Endopiriform nucleus -- EP -- id 942 -- expression_density = 0.0379623
# Primary somatosensory area, upper limb, layer 6a -- SSp-ul6a -- id 945 -- expression_density = 0.040878
# Endopiriform nucleus, dorsal part -- EPd -- id 952 -- expression_density = 0.0478363
# Primary auditory area, layer 6a -- AUDp6a -- id 954 -- expression_density = 0.0104962
# Piriform area -- PIR -- id 961 -- expression_density = 0.0141158
# Primary somatosensory area, mouth, layer 5 -- SSp-m5 -- id 974 -- expression_density = 0.0173888
# Primary auditory area -- AUDp -- id 1002 -- expression_density = 0.0152982
# Primary auditory area, layer 6b -- AUDp6b -- id 1005 -- expression_density = 0.0221581
# Ventral auditory area -- AUDv -- id 1018 -- expression_density = 0.0490637
# Primary somatosensory area, upper limb, layer 6b -- SSp-ul6b -- id 1026 -- expression_density = 0.0633553
# Primary somatosensory area, barrel field, layer 6a -- SSp-bfd6a -- id 1038 -- expression_density = 0.0230283
# Ectorhinal area/Layer 6b -- ECT6b -- id 1045 -- expression_density = 0.0310175
# Gustatory areas -- GU -- id 1057 -- expression_density = 0.037086
# Visceral area, layer 5 -- VISC5 -- id 1058 -- expression_density = 0.0107038
# Primary somatosensory area, barrel field, layer 6b -- SSp-bfd6b -- id 1062 -- expression_density = 0.0438428
# Agranular insular area, dorsal part, layer 5 -- AId5 -- id 1101 -- expression_density = 0.0450697
# Primary somatosensory area, mouth, layer 6a -- SSp-m6a -- id 1102 -- expression_density = 0.0630804
# Primary somatosensory area, unassigned -- SSp-un -- id 182305689 -- expression_density = 0.0150012
# Primary somatosensory area, unassigned, layer 5 -- SSp-un5 -- id 182305705 -- expression_density = 0.013126
# Primary somatosensory area, unassigned, layer 6a -- SSp-un6a -- id 182305709 -- expression_density = 0.0567438
# Primary somatosensory area, unassigned, layer 6b -- SSp-un6b -- id 182305713 -- expression_density = 0.0174315

# %% [markdown]
# ### Only getting the visual areas from unionized data

# %%
# The ID that has to be within structure_id_path of structures in unionized data
PARENT_AREA_ID = 669 # all visual areas

# %%
newdf.head()
# Out:
#      expression_density  expression_energy         id  section_data_set_id  \
# 2              0.010952            1.48177  398484604                  353
# 3              0.012336            1.67205  398484612                  353
# 129            0.012872            1.74500  398485707                  353
# 130            0.013192            1.78865  398485714                  353
# 131            0.012700            1.60243  398485727                  353
#
#      structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 2           15566                    1.148940e+09             8491790.00
# 3           15567                    1.135570e+09             8378020.00
# 129         15738                    1.132940e+09             8357250.00
# 130         15739                    1.132200e+09             8350710.00
# 131         15740                    1.681060e+05                1332.34
#
#      sum_pixel_intensity   sum_pixels  voxel_energy_cv  voxel_energy_mean
# 2           1.678110e+10  775383000.0          2.32817            1.48118
# 3           1.474800e+10  679149000.0          2.18009            1.67129
# 129         1.428170e+10  649250000.0          2.12707            1.74417
# 130         1.398700e+10  632990000.0          2.09599            1.78778
# 131         2.452430e+06     104907.0          1.52667            1.60243

# %%
def query_id_path(s_id):
    query = rma.model_query('StructureLookup', criteria="structure[id$eq"+str(s_id)+"]",include="structure",
        options="[only$eq'structure_lookups.termtype,structure_lookups.structure_id_path']")[0]
    return query['structure']['structure_id_path']

# %%
print(query_id_path(15566))
# Out:
# /15564/15565/15566/

# %%
for s_id in tqdm(newdf['structure_id'],'Searching for data from visual areas'):
    hasParentInPath = str(PARENT_AREA_ID) in query_id_path(s_id)
    if hasParentInPath: 
        print(newdf[newdf['structure_id']==s_id])
# Out:
# Searching for data from visual areas:   0%|          | 0/205 [00:00<?, ?it/s]
#       expression_density  expression_energy         id  section_data_set_id  \
# 1935            0.010856            1.51132  398512408                  353
#
#       structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 1935           501                        369944.0                2657.45
#
#       sum_pixel_intensity  sum_pixels  voxel_energy_cv  voxel_energy_mean
# 1935            5906550.0    244783.0         0.719633            1.51132

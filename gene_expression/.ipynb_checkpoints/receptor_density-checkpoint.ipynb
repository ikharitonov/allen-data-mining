# %% [markdown]
# # Receptor Density - Gene Expression Data
#
#
# General API guide: http://help.brain-map.org/display/mousebrain/API
#
# General RMA Guide http://help.brain-map.org/pages/viewpage.action?pageId=5308449
#
# Class Hierarchy http://api.brain-map.org/class_hierarchy
#
# Examples RMA URL Queries http://help.brain-map.org/display/api/Example+Queries+for+Experiment+Metadata
#
# Python API Queries https://alleninstitute.github.io/AllenSDK/data_api_client.html
#
# RMA Query Building Web Application http://api.brain-map.org/examples/rma_builder/index.html

# %% [markdown]
# ### Informatics Data Processing
# The informatics data processing pipeline produces results that enable the navigation, analysis and visualization. The pipeline consists of the following components:
# - an annotated 3-D reference space,
# - an alignment module,
# - an expression detection module,
# - an expression gridding module, and
# - a structure unionizer module.
#
# The output of the pipeline is quantified expression values at a grid voxel level and at a structure level according to the integrated reference atlas ontology. The grid level data are used downstream to provide a differential and correlative gene search service and to support visualization of spatial relationships.

# %%
from allensdk.api.queries.rma_api import RmaApi
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

rma = RmaApi()

# %% [markdown]
# Get experiments for a particular gene - DRD1

# %%
# http://api.brain-map.org/api/v2/data/query.xml?criteria=
# model::SectionDataSet
# ,
# rma::criteria,
# products[abbreviation$eqMouse],genes[acronym$eqDrd1]
# ,
# rma::include,
# structure_unionizes

gene = "Drd1"
        
data = rma.model_query('SectionDataSet', criteria="products[abbreviation$eq'Mouse'],genes[acronym$eq'"+gene+"']",
                      include="structure_unionizes")

# %%
data_df = pd.DataFrame(data)
data_df
# Out:
#   blue_channel  delegate  expression  failed  failed_facet green_channel  \
# 0         None      True        True   False     734881840          None
# 1         None     False       False   False     734881840          None
# 2         None     False       False   False     734881840          None
# 3         None     False       False   False     734881840          None
#
#          id  name  plane_of_section_id               qc_date red_channel  \
# 0  71307280  None                    2  2009-05-02T22:56:37Z        None
# 1       352  None                    1                  None        None
# 2       353  None                    2                  None        None
# 3       354  None                    2                  None        None
#
#    reference_space_id rnaseq_design_id  section_thickness  specimen_id  \
# 0                  10             None               25.0     70429761
# 1                   9             None               25.0       702565
# 2                  10             None               25.0       702529
# 3                  10             None               25.0       702473
#
#    sphinx_id                                  storage_directory  weight  \
# 0     150678  /external/aibssan/production32/prod334/image_s...    5470
# 1      78451            /external/mouse/prod1/image_series_352/    5470
# 2      76510            /external/mouse/prod1/image_series_353/    5470
# 3      95220            /external/mouse/prod0/image_series_354/    5270
#
#                                  structure_unionizes
# 0  [{'expression_density': 0.0159272, 'expression...
# 1  [{'expression_density': 0.0136562, 'expression...
# 2  [{'expression_density': 0.00817143, 'expressio...
# 3  [{'expression_density': 7.11597e-05, 'expressi...

# %%
experiment_id = 353
param = 'expression_density'

# %%
exp_union_data = pd.DataFrame(data_df[data_df['id']==experiment_id]['structure_unionizes'].item())
exp_union_data
# Out:
#       expression_density  expression_energy         id  section_data_set_id  \
# 0               0.008171           1.097120  398484594                  353
# 1               0.008171           1.097120  398484597                  353
# 2               0.010952           1.481770  398484604                  353
# 3               0.012336           1.672050  398484612                  353
# 4               0.000695           0.087989  398484614                  353
# ...                  ...                ...        ...                  ...
# 2404            0.000198           0.024448  398520317                  353
# 2405            0.000662           0.083920  398520335                  353
# 2406            0.013126           1.778890  398520348                  353
# 2407            0.056744           7.730210  398520360                  353
# 2408            0.017431           2.276720  398520372                  353
#
#       structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0            15564                    1.247590e+09            9292150.000
# 1            15565                    1.247590e+09            9292150.000
# 2            15566                    1.148940e+09            8491790.000
# 3            15567                    1.135570e+09            8378020.000
# 4            15568                    2.630740e+06              20770.700
# ...            ...                             ...                    ...
# 2404     182305697                    4.274550e+04                345.941
# 2405     182305701                    4.108420e+04                323.881
# 2406     182305705                    3.172510e+06              23409.100
# 2407     182305709                    8.920480e+06              65481.100
# 2408     182305713                    4.776870e+05               3657.380
#
#       sum_pixel_intensity    sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0            2.520100e+10  1.137150e+09         2.657610           1.096010
# 1            2.520100e+10  1.137150e+09         2.657610           1.096010
# 2            1.678110e+10  7.753830e+08         2.328170           1.481180
# 3            1.474800e+10  6.791490e+08         2.180090           1.671290
# 4            4.662790e+08  2.989850e+07         2.344180           0.087989
# ...                   ...           ...              ...                ...
# 2404         3.581480e+07  1.748450e+06         1.518590           0.024448
# 2405         1.085670e+07  4.895660e+05         1.072950           0.083920
# 2406         4.605390e+07  1.783420e+06         1.291390           1.778890
# 2407         3.937200e+07  1.153980e+06         0.826628           7.730210
# 2408         4.907160e+06  2.098140e+05         2.107130           2.276720
#
# [2409 rows x 11 columns]

# %%
newdf = exp_union_data[exp_union_data[param] > 0.01]

# %%
plt.hist(newdf[param])
plt.show()

# %%
len(newdf['structure_id'].unique())
# Out:
# 205

# %%
print(len(newdf['structure_id']))
print(len(newdf['structure_id'].unique()))
print(newdf[newdf['structure_id']==15850][param])
# Out:
# 205
# 205
# 211    0.07296
# Name: expression_density, dtype: float64

# %%
# printing structure name, id and expression density for all unionized data points

# for s_id in newdf['structure_id'].unique():
#     structure = rma.model_query('StructureLookup', criteria="structure[id$eq"+str(s_id)+"]",include="structure")[0]
#     print(structure['structure']['name'],'--',structure['structure']['acronym'],'--','id',s_id,'--',param,'=',newdf[newdf['structure_id']==s_id][param].item())

# %% [markdown]
# ### Only getting the visual areas from unionized data

# %%
# The ID that has to be within structure_id_path of structures in unionized data
PARENT_AREA_ID = 669 # all visual areas

# %%
newdf.head()
# Out:
#      expression_density  expression_energy         id  section_data_set_id  \
# 2              0.010952            1.48177  398484604                  353
# 3              0.012336            1.67205  398484612                  353
# 129            0.012872            1.74500  398485707                  353
# 130            0.013192            1.78865  398485714                  353
# 131            0.012700            1.60243  398485727                  353
#
#      structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 2           15566                    1.148940e+09             8491790.00
# 3           15567                    1.135570e+09             8378020.00
# 129         15738                    1.132940e+09             8357250.00
# 130         15739                    1.132200e+09             8350710.00
# 131         15740                    1.681060e+05                1332.34
#
#      sum_pixel_intensity   sum_pixels  voxel_energy_cv  voxel_energy_mean
# 2           1.678110e+10  775383000.0          2.32817            1.48118
# 3           1.474800e+10  679149000.0          2.18009            1.67129
# 129         1.428170e+10  649250000.0          2.12707            1.74417
# 130         1.398700e+10  632990000.0          2.09599            1.78778
# 131         2.452430e+06     104907.0          1.52667            1.60243

# %%
def query_id_path(s_id):
    query = rma.model_query('StructureLookup', criteria="structure[id$eq"+str(s_id)+"]",include="structure",
        options="[only$eq'structure_lookups.termtype,structure_lookups.structure_id_path']")[0]
    return query['structure']['structure_id_path']

# %%
print(query_id_path(15566))
# Out:
# /15564/15565/15566/

# %%
# dict(newdf[newdf['structure_id']==15566])
# newdf[newdf['structure_id']==15566].to_dict('records')
pd.DataFrame(newdf[newdf['structure_id']==15566].to_dict('records'))
# Out:
#    expression_density  expression_energy         id  section_data_set_id  \
# 0            0.010952            1.48177  398484604                  353
#
#    structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0         15566                    1.148940e+09              8491790.0
#
#    sum_pixel_intensity   sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0         1.678110e+10  775383000.0          2.32817            1.48118

# %%
out_df = []
for s_id in tqdm(newdf['structure_id'],'Searching for data from visual areas'):
    hasParentInPath = str(PARENT_AREA_ID) in query_id_path(s_id)
    if hasParentInPath:
        out_df.append(newdf[newdf['structure_id']==s_id].to_dict('records')[0])
#         print(newdf[newdf['structure_id']==s_id])
out_df = pd.DataFrame(out_df)
# Out:
# Searching for data from visual areas:   0%|                                                    | 0/205 [00:00<?, ?it/s]
#
# Searching for data from visual areas:   0%|▏                                           | 1/205 [00:00<01:30,  2.25it/s]
#
# Searching for data from visual areas:   1%|▍                                           | 2/205 [00:00<01:22,  2.45it/s]
#
# Searching for data from visual areas:   1%|▋                                           | 3/205 [00:01<01:21,  2.49it/s]
#
# Searching for data from visual areas:   2%|▊                                           | 4/205 [00:01<01:19,  2.54it/s]
#
# Searching for data from visual areas:   2%|█                                           | 5/205 [00:01<01:18,  2.54it/s]
#
# Searching for data from visual areas:   3%|█▎                                          | 6/205 [00:02<01:17,  2.57it/s]
#
# Searching for data from visual areas:   3%|█▌                                          | 7/205 [00:02<01:17,  2.57it/s]
#
# Searching for data from visual areas:   4%|█▋                                          | 8/205 [00:03<01:16,  2.58it/s]
#
# Searching for data from visual areas:   4%|█▉                                          | 9/205 [00:03<01:17,  2.53it/s]
#
# Searching for data from visual areas:   5%|██                                         | 10/205 [00:03<01:16,  2.56it/s]
#
# Searching for data from visual areas:   5%|██▎                                        | 11/205 [00:04<01:15,  2.56it/s]
#
# Searching for data from visual areas:   6%|██▌                                        | 12/205 [00:04<01:14,  2.58it/s]
#
# Searching for data from visual areas:   6%|██▋                                        | 13/205 [00:05<01:15,  2.55it/s]
#
# Searching for data from visual areas:   7%|██▉                                        | 14/205 [00:05<01:16,  2.49it/s]
#
# Searching for data from visual areas:   7%|███▏                                       | 15/205 [00:05<01:18,  2.42it/s]
#
# Searching for data from visual areas:   8%|███▎                                       | 16/205 [00:06<01:18,  2.41it/s]
#
# Searching for data from visual areas:   8%|███▌                                       | 17/205 [00:06<01:19,  2.37it/s]
#
# Searching for data from visual areas:   9%|███▊                                       | 18/205 [00:07<01:17,  2.41it/s]
#
# Searching for data from visual areas:   9%|███▉                                       | 19/205 [00:07<01:15,  2.46it/s]
#
# Searching for data from visual areas:  10%|████▏                                      | 20/205 [00:08<01:13,  2.51it/s]
#
# Searching for data from visual areas:  10%|████▍                                      | 21/205 [00:08<01:13,  2.51it/s]
#
# Searching for data from visual areas:  11%|████▌                                      | 22/205 [00:08<01:13,  2.50it/s]
#
# Searching for data from visual areas:  11%|████▊                                      | 23/205 [00:09<01:12,  2.51it/s]
#
# Searching for data from visual areas:  12%|█████                                      | 24/205 [00:09<01:11,  2.54it/s]
#
# Searching for data from visual areas:  12%|█████▏                                     | 25/205 [00:09<01:10,  2.56it/s]
#
# Searching for data from visual areas:  13%|█████▍                                     | 26/205 [00:10<01:09,  2.58it/s]
#
# Searching for data from visual areas:  13%|█████▋                                     | 27/205 [00:10<01:10,  2.52it/s]
#
# Searching for data from visual areas:  14%|█████▊                                     | 28/205 [00:11<01:13,  2.42it/s]
#
# Searching for data from visual areas:  14%|██████                                     | 29/205 [00:11<01:11,  2.45it/s]
#
# Searching for data from visual areas:  15%|██████▎                                    | 30/205 [00:11<01:09,  2.51it/s]
#
# Searching for data from visual areas:  15%|██████▌                                    | 31/205 [00:12<01:08,  2.53it/s]
#
# Searching for data from visual areas:  16%|██████▋                                    | 32/205 [00:12<01:07,  2.56it/s]
#
# Searching for data from visual areas:  16%|██████▉                                    | 33/205 [00:13<01:06,  2.60it/s]
#
# Searching for data from visual areas:  17%|███████▏                                   | 34/205 [00:13<01:05,  2.60it/s]
#
# Searching for data from visual areas:  17%|███████▎                                   | 35/205 [00:13<01:05,  2.59it/s]
#
# Searching for data from visual areas:  18%|███████▌                                   | 36/205 [00:14<01:05,  2.56it/s]
#
# Searching for data from visual areas:  18%|███████▊                                   | 37/205 [00:14<01:05,  2.57it/s]
#
# Searching for data from visual areas:  19%|███████▉                                   | 38/205 [00:15<01:05,  2.56it/s]
#
# Searching for data from visual areas:  19%|████████▏                                  | 39/205 [00:15<01:03,  2.60it/s]
#
# Searching for data from visual areas:  20%|████████▍                                  | 40/205 [00:15<01:03,  2.60it/s]
#
# Searching for data from visual areas:  20%|████████▌                                  | 41/205 [00:16<01:03,  2.60it/s]
#
# Searching for data from visual areas:  20%|████████▊                                  | 42/205 [00:16<01:03,  2.59it/s]
#
# Searching for data from visual areas:  21%|█████████                                  | 43/205 [00:16<01:02,  2.60it/s]
#
# Searching for data from visual areas:  21%|█████████▏                                 | 44/205 [00:17<01:03,  2.55it/s]
#
# Searching for data from visual areas:  22%|█████████▍                                 | 45/205 [00:17<01:03,  2.53it/s]
#
# Searching for data from visual areas:  22%|█████████▋                                 | 46/205 [00:18<01:02,  2.54it/s]
#
# Searching for data from visual areas:  23%|█████████▊                                 | 47/205 [00:18<01:04,  2.46it/s]
#
# Searching for data from visual areas:  23%|██████████                                 | 48/205 [00:19<01:05,  2.40it/s]
#
# Searching for data from visual areas:  24%|██████████▎                                | 49/205 [00:19<01:03,  2.44it/s]
#
# Searching for data from visual areas:  24%|██████████▍                                | 50/205 [00:19<01:02,  2.49it/s]
#
# Searching for data from visual areas:  25%|██████████▋                                | 51/205 [00:20<01:01,  2.52it/s]
#
# Searching for data from visual areas:  25%|██████████▉                                | 52/205 [00:20<01:01,  2.48it/s]
#
# Searching for data from visual areas:  26%|███████████                                | 53/205 [00:21<01:00,  2.51it/s]
#
# Searching for data from visual areas:  26%|███████████▎                               | 54/205 [00:21<01:00,  2.50it/s]
#
# Searching for data from visual areas:  27%|███████████▌                               | 55/205 [00:21<00:58,  2.55it/s]
#
# Searching for data from visual areas:  27%|███████████▋                               | 56/205 [00:22<00:58,  2.55it/s]
#
# Searching for data from visual areas:  28%|███████████▉                               | 57/205 [00:22<00:57,  2.57it/s]
#
# Searching for data from visual areas:  28%|████████████▏                              | 58/205 [00:22<00:57,  2.55it/s]
#
# Searching for data from visual areas:  29%|████████████▍                              | 59/205 [00:23<00:59,  2.46it/s]
#
# Searching for data from visual areas:  29%|████████████▌                              | 60/205 [00:23<01:00,  2.40it/s]
#
# Searching for data from visual areas:  30%|████████████▊                              | 61/205 [00:24<01:01,  2.35it/s]
#
# Searching for data from visual areas:  30%|█████████████                              | 62/205 [00:24<00:59,  2.41it/s]
#
# Searching for data from visual areas:  31%|█████████████▏                             | 63/205 [00:25<00:57,  2.46it/s]
# Searching for data from visual areas:  31%|█████████████▍                             | 64/205 [00:25<00:58,  2.43it/s]
#
# Searching for data from visual areas:  32%|█████████████▋                             | 65/205 [00:25<00:56,  2.46it/s]
#
# Searching for data from visual areas:  32%|█████████████▊                             | 66/205 [00:26<00:55,  2.52it/s]
#
# Searching for data from visual areas:  33%|██████████████                             | 67/205 [00:26<00:54,  2.55it/s]
#
# Searching for data from visual areas:  33%|██████████████▎                            | 68/205 [00:27<00:52,  2.59it/s]
#
# Searching for data from visual areas:  34%|██████████████▍                            | 69/205 [00:27<00:53,  2.56it/s]
#
# Searching for data from visual areas:  34%|██████████████▋                            | 70/205 [00:27<00:52,  2.59it/s]
#
# Searching for data from visual areas:  35%|██████████████▉                            | 71/205 [00:28<00:52,  2.54it/s]
#
# Searching for data from visual areas:  35%|███████████████                            | 72/205 [00:28<00:54,  2.45it/s]
#
# Searching for data from visual areas:  36%|███████████████▎                           | 73/205 [00:29<00:55,  2.39it/s]
#
# Searching for data from visual areas:  36%|███████████████▌                           | 74/205 [00:29<00:53,  2.46it/s]
#
# Searching for data from visual areas:  37%|███████████████▋                           | 75/205 [00:29<00:52,  2.49it/s]
#
# Searching for data from visual areas:  37%|███████████████▉                           | 76/205 [00:30<00:52,  2.46it/s]
#
# Searching for data from visual areas:  38%|████████████████▏                          | 77/205 [00:30<00:51,  2.49it/s]
#
# Searching for data from visual areas:  38%|████████████████▎                          | 78/205 [00:31<00:50,  2.53it/s]
#
# Searching for data from visual areas:  39%|████████████████▌                          | 79/205 [00:31<00:49,  2.55it/s]
#
# Searching for data from visual areas:  39%|████████████████▊                          | 80/205 [00:31<00:49,  2.55it/s]
#
# Searching for data from visual areas:  40%|████████████████▉                          | 81/205 [00:32<00:48,  2.56it/s]
#
# Searching for data from visual areas:  40%|█████████████████▏                         | 82/205 [00:32<00:47,  2.59it/s]
#
# Searching for data from visual areas:  40%|█████████████████▍                         | 83/205 [00:32<00:47,  2.59it/s]
#
# Searching for data from visual areas:  41%|█████████████████▌                         | 84/205 [00:33<00:46,  2.60it/s]
#
# Searching for data from visual areas:  41%|█████████████████▊                         | 85/205 [00:33<00:46,  2.58it/s]
#
# Searching for data from visual areas:  42%|██████████████████                         | 86/205 [00:34<00:45,  2.61it/s]
#
# Searching for data from visual areas:  42%|██████████████████▏                        | 87/205 [00:34<00:46,  2.56it/s]
#
# Searching for data from visual areas:  43%|██████████████████▍                        | 88/205 [00:34<00:45,  2.57it/s]
#
# Searching for data from visual areas:  43%|██████████████████▋                        | 89/205 [00:35<00:44,  2.58it/s]
#
# Searching for data from visual areas:  44%|██████████████████▉                        | 90/205 [00:35<00:44,  2.58it/s]
#
# Searching for data from visual areas:  44%|███████████████████                        | 91/205 [00:36<00:44,  2.57it/s]
#
# Searching for data from visual areas:  45%|███████████████████▎                       | 92/205 [00:36<00:44,  2.54it/s]
#
# Searching for data from visual areas:  45%|███████████████████▌                       | 93/205 [00:36<00:44,  2.53it/s]
#
# Searching for data from visual areas:  46%|███████████████████▋                       | 94/205 [00:37<00:43,  2.56it/s]
#
# Searching for data from visual areas:  46%|███████████████████▉                       | 95/205 [00:37<00:43,  2.55it/s]
#
# Searching for data from visual areas:  47%|████████████████████▏                      | 96/205 [00:38<00:42,  2.57it/s]
#
# Searching for data from visual areas:  47%|████████████████████▎                      | 97/205 [00:38<00:43,  2.49it/s]
#
# Searching for data from visual areas:  48%|████████████████████▌                      | 98/205 [00:38<00:42,  2.53it/s]
#
# Searching for data from visual areas:  48%|████████████████████▊                      | 99/205 [00:39<00:42,  2.52it/s]
#
# Searching for data from visual areas:  49%|████████████████████▍                     | 100/205 [00:39<00:41,  2.56it/s]
#
# Searching for data from visual areas:  49%|████████████████████▋                     | 101/205 [00:40<00:42,  2.46it/s]
#
# Searching for data from visual areas:  50%|████████████████████▉                     | 102/205 [00:40<00:41,  2.45it/s]
#
# Searching for data from visual areas:  50%|█████████████████████                     | 103/205 [00:40<00:41,  2.43it/s]
#
# Searching for data from visual areas:  51%|█████████████████████▎                    | 104/205 [00:41<00:41,  2.44it/s]
#
# Searching for data from visual areas:  51%|█████████████████████▌                    | 105/205 [00:41<00:40,  2.48it/s]
#
# Searching for data from visual areas:  52%|█████████████████████▋                    | 106/205 [00:42<00:39,  2.52it/s]
#
# Searching for data from visual areas:  52%|█████████████████████▉                    | 107/205 [00:42<00:38,  2.52it/s]
#
# Searching for data from visual areas:  53%|██████████████████████▏                   | 108/205 [00:42<00:37,  2.57it/s]
#
# Searching for data from visual areas:  53%|██████████████████████▎                   | 109/205 [00:43<00:38,  2.50it/s]
#
# Searching for data from visual areas:  54%|██████████████████████▌                   | 110/205 [00:43<00:37,  2.55it/s]
#
# Searching for data from visual areas:  54%|██████████████████████▋                   | 111/205 [00:44<00:36,  2.56it/s]
#
# Searching for data from visual areas:  55%|██████████████████████▉                   | 112/205 [00:44<00:36,  2.53it/s]
#
# Searching for data from visual areas:  55%|███████████████████████▏                  | 113/205 [00:44<00:37,  2.47it/s]
#
# Searching for data from visual areas:  56%|███████████████████████▎                  | 114/205 [00:45<00:38,  2.39it/s]
#
# Searching for data from visual areas:  56%|███████████████████████▌                  | 115/205 [00:45<00:37,  2.40it/s]
#
# Searching for data from visual areas:  57%|███████████████████████▊                  | 116/205 [00:46<00:36,  2.47it/s]
#
# Searching for data from visual areas:  57%|███████████████████████▉                  | 117/205 [00:46<00:36,  2.40it/s]
#
# Searching for data from visual areas:  58%|████████████████████████▏                 | 118/205 [00:46<00:35,  2.48it/s]
#
# Searching for data from visual areas:  58%|████████████████████████▍                 | 119/205 [00:47<00:34,  2.50it/s]
#
# Searching for data from visual areas:  59%|████████████████████████▌                 | 120/205 [00:47<00:33,  2.54it/s]
#
# Searching for data from visual areas:  59%|████████████████████████▊                 | 121/205 [00:48<00:32,  2.55it/s]
#
# Searching for data from visual areas:  60%|████████████████████████▉                 | 122/205 [00:48<00:33,  2.48it/s]
#
# Searching for data from visual areas:  60%|█████████████████████████▏                | 123/205 [00:48<00:32,  2.52it/s]
#
# Searching for data from visual areas:  60%|█████████████████████████▍                | 124/205 [00:49<00:31,  2.55it/s]
#
# Searching for data from visual areas:  61%|█████████████████████████▌                | 125/205 [00:49<00:31,  2.55it/s]
#
# Searching for data from visual areas:  61%|█████████████████████████▊                | 126/205 [00:50<00:32,  2.46it/s]
#
# Searching for data from visual areas:  62%|██████████████████████████                | 127/205 [00:50<00:34,  2.25it/s]
# Searching for data from visual areas:  62%|██████████████████████████▏               | 128/205 [00:51<00:32,  2.33it/s]
#
# Searching for data from visual areas:  63%|██████████████████████████▍               | 129/205 [00:51<00:31,  2.40it/s]
#
# Searching for data from visual areas:  63%|██████████████████████████▋               | 130/205 [00:51<00:30,  2.44it/s]
#
# Searching for data from visual areas:  64%|██████████████████████████▊               | 131/205 [00:52<00:29,  2.49it/s]
#
# Searching for data from visual areas:  64%|███████████████████████████               | 132/205 [00:52<00:29,  2.49it/s]
#
# Searching for data from visual areas:  65%|███████████████████████████▏              | 133/205 [00:52<00:28,  2.54it/s]
#
# Searching for data from visual areas:  65%|███████████████████████████▍              | 134/205 [00:53<00:28,  2.52it/s]
#
# Searching for data from visual areas:  66%|███████████████████████████▋              | 135/205 [00:53<00:27,  2.56it/s]
#
# Searching for data from visual areas:  66%|███████████████████████████▊              | 136/205 [00:54<00:28,  2.46it/s]
#
# Searching for data from visual areas:  67%|████████████████████████████              | 137/205 [00:54<00:27,  2.51it/s]
#
# Searching for data from visual areas:  67%|████████████████████████████▎             | 138/205 [00:54<00:26,  2.50it/s]
#
# Searching for data from visual areas:  68%|████████████████████████████▍             | 139/205 [00:55<00:25,  2.54it/s]
#
# Searching for data from visual areas:  68%|████████████████████████████▋             | 140/205 [00:55<00:25,  2.51it/s]
#
# Searching for data from visual areas:  69%|████████████████████████████▉             | 141/205 [00:56<00:26,  2.41it/s]
#
# Searching for data from visual areas:  69%|█████████████████████████████             | 142/205 [00:56<00:25,  2.48it/s]
#
# Searching for data from visual areas:  70%|█████████████████████████████▎            | 143/205 [00:56<00:24,  2.53it/s]
#
# Searching for data from visual areas:  70%|█████████████████████████████▌            | 144/205 [00:57<00:24,  2.54it/s]
#
# Searching for data from visual areas:  71%|█████████████████████████████▋            | 145/205 [00:57<00:23,  2.57it/s]
#
# Searching for data from visual areas:  71%|█████████████████████████████▉            | 146/205 [00:58<00:23,  2.52it/s]
#
# Searching for data from visual areas:  72%|██████████████████████████████            | 147/205 [01:01<01:18,  1.36s/it]
#
# Searching for data from visual areas:  72%|██████████████████████████████▎           | 148/205 [01:02<01:01,  1.08s/it]
#
# Searching for data from visual areas:  73%|██████████████████████████████▌           | 149/205 [01:02<00:48,  1.15it/s]
#
# Searching for data from visual areas:  73%|██████████████████████████████▋           | 150/205 [01:02<00:39,  1.38it/s]
#
# Searching for data from visual areas:  74%|██████████████████████████████▉           | 151/205 [01:03<00:33,  1.61it/s]
#
# Searching for data from visual areas:  74%|███████████████████████████████▏          | 152/205 [01:03<00:29,  1.82it/s]
#
# Searching for data from visual areas:  75%|███████████████████████████████▎          | 153/205 [01:04<00:25,  2.01it/s]
#
# Searching for data from visual areas:  75%|███████████████████████████████▌          | 154/205 [01:04<00:23,  2.14it/s]
#
# Searching for data from visual areas:  76%|███████████████████████████████▊          | 155/205 [01:04<00:22,  2.27it/s]
#
# Searching for data from visual areas:  76%|███████████████████████████████▉          | 156/205 [01:05<00:20,  2.35it/s]
#
# Searching for data from visual areas:  77%|████████████████████████████████▏         | 157/205 [01:05<00:20,  2.37it/s]
#
# Searching for data from visual areas:  77%|████████████████████████████████▎         | 158/205 [01:06<00:19,  2.44it/s]
#
# Searching for data from visual areas:  78%|████████████████████████████████▌         | 159/205 [01:06<00:18,  2.50it/s]
#
# Searching for data from visual areas:  78%|████████████████████████████████▊         | 160/205 [01:06<00:18,  2.49it/s]
#
# Searching for data from visual areas:  79%|████████████████████████████████▉         | 161/205 [01:07<00:17,  2.52it/s]
#
# Searching for data from visual areas:  79%|█████████████████████████████████▏        | 162/205 [01:07<00:16,  2.54it/s]
#
# Searching for data from visual areas:  80%|█████████████████████████████████▍        | 163/205 [01:08<00:16,  2.57it/s]
#
# Searching for data from visual areas:  80%|█████████████████████████████████▌        | 164/205 [01:08<00:15,  2.57it/s]
#
# Searching for data from visual areas:  80%|█████████████████████████████████▊        | 165/205 [01:08<00:15,  2.57it/s]
#
# Searching for data from visual areas:  81%|██████████████████████████████████        | 166/205 [01:09<00:15,  2.59it/s]
#
# Searching for data from visual areas:  81%|██████████████████████████████████▏       | 167/205 [01:09<00:14,  2.59it/s]
#
# Searching for data from visual areas:  82%|██████████████████████████████████▍       | 168/205 [01:09<00:14,  2.59it/s]
#
# Searching for data from visual areas:  82%|██████████████████████████████████▌       | 169/205 [01:10<00:14,  2.56it/s]
#
# Searching for data from visual areas:  83%|██████████████████████████████████▊       | 170/205 [01:10<00:14,  2.46it/s]
#
# Searching for data from visual areas:  83%|███████████████████████████████████       | 171/205 [01:11<00:13,  2.52it/s]
#
# Searching for data from visual areas:  84%|███████████████████████████████████▏      | 172/205 [01:11<00:12,  2.55it/s]
#
# Searching for data from visual areas:  84%|███████████████████████████████████▍      | 173/205 [01:11<00:12,  2.56it/s]
#
# Searching for data from visual areas:  85%|███████████████████████████████████▋      | 174/205 [01:12<00:12,  2.55it/s]
#
# Searching for data from visual areas:  85%|███████████████████████████████████▊      | 175/205 [01:12<00:11,  2.56it/s]
#
# Searching for data from visual areas:  86%|████████████████████████████████████      | 176/205 [01:13<00:11,  2.55it/s]
#
# Searching for data from visual areas:  86%|████████████████████████████████████▎     | 177/205 [01:13<00:10,  2.59it/s]
#
# Searching for data from visual areas:  87%|████████████████████████████████████▍     | 178/205 [01:13<00:10,  2.59it/s]
#
# Searching for data from visual areas:  87%|████████████████████████████████████▋     | 179/205 [01:14<00:10,  2.52it/s]
#
# Searching for data from visual areas:  88%|████████████████████████████████████▉     | 180/205 [01:14<00:10,  2.38it/s]
#
# Searching for data from visual areas:  88%|█████████████████████████████████████     | 181/205 [01:15<00:09,  2.44it/s]
#
# Searching for data from visual areas:  89%|█████████████████████████████████████▎    | 182/205 [01:15<00:09,  2.40it/s]
#
# Searching for data from visual areas:  89%|█████████████████████████████████████▍    | 183/205 [01:16<00:09,  2.35it/s]
#
# Searching for data from visual areas:  90%|█████████████████████████████████████▋    | 184/205 [01:16<00:09,  2.33it/s]
#
# Searching for data from visual areas:  90%|█████████████████████████████████████▉    | 185/205 [01:16<00:08,  2.42it/s]
#
# Searching for data from visual areas:  91%|██████████████████████████████████████    | 186/205 [01:17<00:07,  2.45it/s]
#
# Searching for data from visual areas:  91%|██████████████████████████████████████▎   | 187/205 [01:17<00:07,  2.50it/s]
#
# Searching for data from visual areas:  92%|██████████████████████████████████████▌   | 188/205 [01:18<00:06,  2.52it/s]
#
# Searching for data from visual areas:  92%|██████████████████████████████████████▋   | 189/205 [01:18<00:06,  2.55it/s]
#
# Searching for data from visual areas:  93%|██████████████████████████████████████▉   | 190/205 [01:18<00:05,  2.51it/s]
#
# Searching for data from visual areas:  93%|███████████████████████████████████████▏  | 191/205 [01:19<00:06,  2.22it/s]
# Searching for data from visual areas:  94%|███████████████████████████████████████▎  | 192/205 [01:19<00:05,  2.28it/s]
#
# Searching for data from visual areas:  94%|███████████████████████████████████████▌  | 193/205 [01:20<00:05,  2.38it/s]
#
# Searching for data from visual areas:  95%|███████████████████████████████████████▋  | 194/205 [01:20<00:04,  2.35it/s]
#
# Searching for data from visual areas:  95%|███████████████████████████████████████▉  | 195/205 [01:20<00:04,  2.42it/s]
#
# Searching for data from visual areas:  96%|████████████████████████████████████████▏ | 196/205 [01:21<00:03,  2.47it/s]
#
# Searching for data from visual areas:  96%|████████████████████████████████████████▎ | 197/205 [01:21<00:03,  2.51it/s]
#
# Searching for data from visual areas:  97%|████████████████████████████████████████▌ | 198/205 [01:22<00:02,  2.50it/s]
#
# Searching for data from visual areas:  97%|████████████████████████████████████████▊ | 199/205 [01:22<00:02,  2.54it/s]
#
# Searching for data from visual areas:  98%|████████████████████████████████████████▉ | 200/205 [01:22<00:01,  2.52it/s]
#
# Searching for data from visual areas:  98%|█████████████████████████████████████████▏| 201/205 [01:23<00:01,  2.56it/s]
#
# Searching for data from visual areas:  99%|█████████████████████████████████████████▍| 202/205 [01:23<00:01,  2.58it/s]
#
# Searching for data from visual areas:  99%|█████████████████████████████████████████▌| 203/205 [01:24<00:00,  2.53it/s]
#
# Searching for data from visual areas: 100%|█████████████████████████████████████████▊| 204/205 [01:24<00:00,  2.56it/s]
#
# Searching for data from visual areas: 100%|██████████████████████████████████████████| 205/205 [01:24<00:00,  2.42it/s]

# %%
out_df
# Out:
#    expression_density  expression_energy         id  section_data_set_id  \
# 0            0.010856            1.51132  398512408                  353
#
#    structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0           501                        369944.0                2657.45
#
#    sum_pixel_intensity  sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0            5906550.0    244783.0         0.719633            1.51132

# %%
filename = 'gene_Drd1_exp_353_parent_id_669.csv'
out_df.to_csv(filename, index=False)

# %%
pd.read_csv(filename)
# Out:
#    expression_density  expression_energy         id  section_data_set_id  \
# 0            0.010856            1.51132  398512408                  353
#
#    structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0           501                        369944.0                2657.45
#
#    sum_pixel_intensity  sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0            5906550.0    244783.0         0.719633            1.51132

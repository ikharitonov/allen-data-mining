# %% [markdown]
# # Data Mining Example with AllenSDK
# From https://allensdk.readthedocs.io/en/latest/_static/examples/nb/mouse_connectivity.html

# %%
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
from allensdk.api.queries.ontologies_api import OntologiesApi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
mcc = MouseConnectivityCache()

# %%
structure_tree = mcc.get_structure_tree()

# %%
oapi = OntologiesApi()
structure_set_ids = structure_tree.get_structure_sets()
pd.DataFrame(oapi.get_structure_sets(structure_set_ids))
# Out:
#                                           description         id  \
# 0             List of structures in Isocortex layer 5  667481446
# 1            List of structures in Isocortex layer 6b  667481450
# 2                Summary structures of the cerebellum  688152368
# 3      List of structures for ABA Differential Search         12
# 4   List of valid structures for projection target...  184527634
# 5   Structures whose surfaces are represented by a...  691663206
# 6                  Summary structures of the midbrain  688152365
# 7                   Summary structures of the medulla  688152367
# 8                  Summary structures of the striatum  688152361
# 9   Structures representing subdivisions of the mo...  687527945
# 10    Summary structures of the hippocampal formation  688152359
# 11  List of visual cortex structures targeted for ...  514166994
# 12          Summary structures of the olfactory areas  688152358
# 13  Curated list of non-overlapping substructures ...  167587189
# 14            List of structures in Isocortex layer 4  667481445
# 15  Structures representing the major divisions of...  687527670
# 16                 Summary structures of the pallidum  688152362
# 17  List of Primary injection structures for BDA/A...  114512892
# 18  List of primary AND secondary injection struct...  112905813
# 19   List of structures for ABA Fine Structure Search         10
# 20  List of primary AND secondary injection struct...  112905828
# 21           List of structures in Isocortex layer 6a  667481449
# 22  List of structures representing a areal level ...          3
# 23            List of structures in Isocortex layer 1  667481440
# 24             Summary structures of the hypothalamus  688152364
# 25          List of structures in Isocortex layer 2/3  667481441
# 26                 All mouse visual areas with layers  396673091
# 27        Summary structures of the cortical subplate  688152360
# 28                 Summary structures of the thalamus  688152363
# 29  List of structures representing a coarse level...          2
# 30                Summary structures of the isocortex  688152357
# 31  List of Primary injection structures for Proje...  114512891
# 32                     Summary structures of the pons  688152366
#
#                                                  name
# 0                                   Isocortex layer 5
# 1                                  Isocortex layer 6b
# 2                                          Cerebellum
# 3                           ABA - Differential Search
# 4                  Mouse Connectivity - Target Search
# 5                      Mouse Brain - Has Surface Mesh
# 6                                            Midbrain
# 7                                             Medulla
# 8                                            Striatum
# 9                        Mouse Connectivity - Summary
# 10                              Hippocampal Formation
# 11     Allen Brain Observatory targeted structure set
# 12                                    Olfactory Areas
# 13                         Brain – Summary Structures
# 14                                  Isocortex layer 4
# 15                            Brain - Major Divisions
# 16                                           Pallidum
# 17  Mouse Connectivity - BDA/AAV Primary Injection...
# 18  Mouse Connectivity - BDA/AAV All Injection Str...
# 19                        ABA - Fine Structure Search
# 20  Mouse Connectivity - Projection All Injection ...
# 21                                 Isocortex layer 6a
# 22                                      Mouse - Areas
# 23                                  Isocortex layer 1
# 24                                       Hypothalamus
# 25                                Isocortex layer 2/3
# 26                      Mouse Cell Types - Structures
# 27                                  Cortical Subplate
# 28                                           Thalamus
# 29                                     Mouse - Coarse
# 30                                          Isocortex
# 31  Mouse Connectivity - Projection Primary Inject...
# 32                                               Pons

# %% [markdown]
# ## Visual Areas List

# %%
# SET_ID = 396673091
# SET_ID = 3
SET_ID = 167587189

coarse_set_list = structure_tree.get_structures_by_set_id([SET_ID])
# coarse_set = [{'name': area['name'], 'id': area['id']} for area in coarse_set_list]
coarse_set_df = pd.DataFrame(coarse_set_list)
# print(coarse_set)
coarse_set_df
# Out:
#           acronym  graph_id  graph_order         id  \
# 0             FRP         1            6        184
# 1             MOp         1           18        985
# 2             MOs         1           24        993
# 3           SSp-n         1           44        353
# 4         SSp-bfd         1           51        329
# 5          SSp-ll         1           65        337
# 6           SSp-m         1           72        345
# 7          SSp-ul         1           79        369
# 8          SSp-tr         1           86        361
# 9          SSp-un         1           93  182305689
# 10            SSs         1          100        378
# 11             GU         1          107       1057
# 12           VISC         1          114        677
# 13           AUDd         1          122       1011
# 14           AUDp         1          136       1002
# 15          AUDpo         1          143       1027
# 16           AUDv         1          150       1018
# 17          VISal         1          164        402
# 18          VISam         1          171        394
# 19           VISl         1          178        409
# 20           VISp         1          185        385
# 21          VISpl         1          192        425
# 22          VISpm         1          199        533
# 23          VISli         1          206  312782574
# 24         VISpor         1          213  312782628
# 25           ACAd         1          226         39
# 26           ACAv         1          232         48
# 27             PL         1          238        972
# 28            ILA         1          245         44
# 29           ORBl         1          258        723
# ..            ...       ...          ...        ...
# 286           PPY         1          998       1069
# 287           LAV         1         1002        209
# 288            MV         1         1003        202
# 289          SPIV         1         1004        225
# 290           SUV         1         1005        217
# 291             x         1         1006        765
# 292           XII         1         1007        773
# 293             y         1         1008        781
# 294            RM         1         1011        206
# 295           RPA         1         1012        230
# 296            RO         1         1013        222
# 297          LING         1         1020        912
# 298          CENT         1         1024        920
# 299           CUL         1         1033        928
# 300           DEC         1         1046        936
# 301          FOTU         1         1050        944
# 302           PYR         1         1054        951
# 303           UVU         1         1058        957
# 304           NOD         1         1062        968
# 305           SIM         1         1067       1007
# 306            AN         1         1071       1017
# 307           PRM         1         1080       1025
# 308          COPY         1         1084       1033
# 309           PFL         1         1088       1041
# 310            FL         1         1092       1049
# 311            FN         1         1097        989
# 312            IP         1         1098         91
# 313            DN         1         1099        846
# 314          VeCB         1         1100  589508455
# 315  fiber tracts         1         1101       1009
#
#                                          name      rgb_triplet  \
# 0               Frontal pole, cerebral cortex    [38, 143, 69]
# 1                          Primary motor area    [31, 157, 90]
# 2                        Secondary motor area    [31, 157, 90]
# 3            Primary somatosensory area, nose   [24, 128, 100]
# 4    Primary somatosensory area, barrel field   [24, 128, 100]
# 5      Primary somatosensory area, lower limb   [24, 128, 100]
# 6           Primary somatosensory area, mouth   [24, 128, 100]
# 7      Primary somatosensory area, upper limb   [24, 128, 100]
# 8           Primary somatosensory area, trunk   [24, 128, 100]
# 9      Primary somatosensory area, unassigned   [24, 128, 100]
# 10            Supplemental somatosensory area   [24, 128, 100]
# 11                            Gustatory areas    [0, 156, 117]
# 12                              Visceral area   [17, 173, 131]
# 13                       Dorsal auditory area    [1, 147, 153]
# 14                      Primary auditory area    [1, 147, 153]
# 15                    Posterior auditory area    [1, 147, 153]
# 16                      Ventral auditory area    [1, 147, 153]
# 17                  Anterolateral visual area    [8, 133, 140]
# 18                   Anteromedial visual area    [8, 133, 140]
# 19                        Lateral visual area    [8, 133, 140]
# 20                        Primary visual area    [8, 133, 140]
# 21                 Posterolateral visual area    [8, 133, 140]
# 22                  posteromedial visual area    [8, 133, 140]
# 23                    Laterointermediate area    [8, 133, 140]
# 24                            Postrhinal area    [8, 133, 140]
# 25       Anterior cingulate area, dorsal part   [64, 166, 102]
# 26      Anterior cingulate area, ventral part   [64, 166, 102]
# 27                             Prelimbic area    [47, 168, 80]
# 28                           Infralimbic area    [89, 179, 99]
# 29                 Orbital area, lateral part    [36, 138, 94]
# ..                                        ...              ...
# 286                     Parapyramidal nucleus  [255, 179, 217]
# 287                Lateral vestibular nucleus  [255, 179, 217]
# 288                 Medial vestibular nucleus  [255, 179, 217]
# 289                 Spinal vestibular nucleus  [255, 179, 217]
# 290               Superior vestibular nucleus  [255, 179, 217]
# 291                                 Nucleus x  [255, 179, 217]
# 292                       Hypoglossal nucleus  [255, 179, 217]
# 293                                 Nucleus y  [255, 179, 217]
# 294                      Nucleus raphe magnus  [255, 198, 226]
# 295                    Nucleus raphe pallidus  [255, 198, 226]
# 296                    Nucleus raphe obscurus  [255, 198, 226]
# 297                               Lingula (I)  [255, 252, 145]
# 298                            Central lobule  [255, 252, 145]
# 299                                    Culmen  [255, 252, 145]
# 300                              Declive (VI)  [255, 252, 145]
# 301                 Folium-tuber vermis (VII)  [255, 252, 145]
# 302                            Pyramus (VIII)  [255, 252, 145]
# 303                                Uvula (IX)  [255, 252, 145]
# 304                               Nodulus (X)  [255, 252, 145]
# 305                             Simple lobule  [255, 252, 145]
# 306                           Ansiform lobule  [255, 252, 145]
# 307                         Paramedian lobule  [255, 252, 145]
# 308                          Copula pyramidis  [255, 252, 145]
# 309                             Paraflocculus  [255, 252, 145]
# 310                                 Flocculus  [255, 252, 145]
# 311                         Fastigial nucleus  [255, 253, 188]
# 312                        Interposed nucleus  [255, 253, 188]
# 313                           Dentate nucleus  [255, 253, 188]
# 314               Vestibulocerebellar nucleus  [255, 253, 188]
# 315                              fiber tracts  [204, 204, 204]
#
#                                      structure_id_path  \
# 0                    [997, 8, 567, 688, 695, 315, 184]
# 1               [997, 8, 567, 688, 695, 315, 500, 985]
# 2               [997, 8, 567, 688, 695, 315, 500, 993]
# 3          [997, 8, 567, 688, 695, 315, 453, 322, 353]
# 4          [997, 8, 567, 688, 695, 315, 453, 322, 329]
# 5          [997, 8, 567, 688, 695, 315, 453, 322, 337]
# 6          [997, 8, 567, 688, 695, 315, 453, 322, 345]
# 7          [997, 8, 567, 688, 695, 315, 453, 322, 369]
# 8          [997, 8, 567, 688, 695, 315, 453, 322, 361]
# 9    [997, 8, 567, 688, 695, 315, 453, 322, 182305689]
# 10              [997, 8, 567, 688, 695, 315, 453, 378]
# 11                  [997, 8, 567, 688, 695, 315, 1057]
# 12                   [997, 8, 567, 688, 695, 315, 677]
# 13             [997, 8, 567, 688, 695, 315, 247, 1011]
# 14             [997, 8, 567, 688, 695, 315, 247, 1002]
# 15             [997, 8, 567, 688, 695, 315, 247, 1027]
# 16             [997, 8, 567, 688, 695, 315, 247, 1018]
# 17              [997, 8, 567, 688, 695, 315, 669, 402]
# 18              [997, 8, 567, 688, 695, 315, 669, 394]
# 19              [997, 8, 567, 688, 695, 315, 669, 409]
# 20              [997, 8, 567, 688, 695, 315, 669, 385]
# 21              [997, 8, 567, 688, 695, 315, 669, 425]
# 22              [997, 8, 567, 688, 695, 315, 669, 533]
# 23        [997, 8, 567, 688, 695, 315, 669, 312782574]
# 24        [997, 8, 567, 688, 695, 315, 669, 312782628]
# 25                [997, 8, 567, 688, 695, 315, 31, 39]
# 26                [997, 8, 567, 688, 695, 315, 31, 48]
# 27                   [997, 8, 567, 688, 695, 315, 972]
# 28                    [997, 8, 567, 688, 695, 315, 44]
# 29              [997, 8, 567, 688, 695, 315, 714, 723]
# ..                                                 ...
# 286                [997, 8, 343, 1065, 354, 370, 1069]
# 287            [997, 8, 343, 1065, 354, 370, 701, 209]
# 288            [997, 8, 343, 1065, 354, 370, 701, 202]
# 289            [997, 8, 343, 1065, 354, 370, 701, 225]
# 290            [997, 8, 343, 1065, 354, 370, 701, 217]
# 291                 [997, 8, 343, 1065, 354, 370, 765]
# 292                 [997, 8, 343, 1065, 354, 370, 773]
# 293                 [997, 8, 343, 1065, 354, 370, 781]
# 294                 [997, 8, 343, 1065, 354, 379, 206]
# 295                 [997, 8, 343, 1065, 354, 379, 230]
# 296                 [997, 8, 343, 1065, 354, 379, 222]
# 297                       [997, 8, 512, 528, 645, 912]
# 298                       [997, 8, 512, 528, 645, 920]
# 299                       [997, 8, 512, 528, 645, 928]
# 300                       [997, 8, 512, 528, 645, 936]
# 301                       [997, 8, 512, 528, 645, 944]
# 302                       [997, 8, 512, 528, 645, 951]
# 303                       [997, 8, 512, 528, 645, 957]
# 304                       [997, 8, 512, 528, 645, 968]
# 305                     [997, 8, 512, 528, 1073, 1007]
# 306                     [997, 8, 512, 528, 1073, 1017]
# 307                     [997, 8, 512, 528, 1073, 1025]
# 308                     [997, 8, 512, 528, 1073, 1033]
# 309                     [997, 8, 512, 528, 1073, 1041]
# 310                     [997, 8, 512, 528, 1073, 1049]
# 311                            [997, 8, 512, 519, 989]
# 312                             [997, 8, 512, 519, 91]
# 313                            [997, 8, 512, 519, 846]
# 314                      [997, 8, 512, 519, 589508455]
# 315                                        [997, 1009]
#
#                                      structure_set_ids
# 0    [3, 112905828, 688152357, 691663206, 687527945...
# 1    [112905828, 688152357, 691663206, 687527945, 1...
# 2    [112905828, 688152357, 691663206, 687527945, 1...
# 3    [112905828, 688152357, 691663206, 687527945, 1...
# 4    [112905828, 688152357, 691663206, 687527945, 1...
# 5    [112905828, 688152357, 691663206, 687527945, 1...
#
# [316 rows x 8 columns]

# %% [markdown]
# ### Getting child nodes of an area

# %%
AREA_GROUP_ID = 254

children = structure_tree.children([AREA_GROUP_ID])[0]
pd.DataFrame(children)
# Out:
#   acronym  graph_id  graph_order   id  \
# 0  RSPagl         1          298  894
# 1    RSPd         1          325  879
# 2    RSPv         1          332  886
#
#                                          name     rgb_triplet  \
# 0  Retrosplenial area, lateral agranular part  [26, 166, 152]
# 1             Retrosplenial area, dorsal part  [26, 166, 152]
# 2            Retrosplenial area, ventral part  [26, 166, 152]
#
#                         structure_id_path  \
# 0  [997, 8, 567, 688, 695, 315, 254, 894]
# 1  [997, 8, 567, 688, 695, 315, 254, 879]
# 2  [997, 8, 567, 688, 695, 315, 254, 886]
#
#                                    structure_set_ids
# 0  [112905828, 688152357, 691663206, 687527945, 1...
# 1  [112905828, 688152357, 691663206, 687527945, 1...
# 2  [112905828, 688152357, 691663206, 687527945, 1...

# %% [markdown]
# ## Getting list of experiements with injection in visual areas

# %%
# # AREA_ID = 402 # Anterolateral visual area
# # AREA_ID = 254 # RSP
# # AREA_ID = 31 # ACA
# AREA_ID = 714 # ORB

# # injection_area = structure_tree.get_structures_by_id([AREA_ID])
# experiments = mcc.get_experiments(injection_structure_ids=[AREA_ID], cre=False)

# print("%d total experiments found." % len(experiments))

# %% [markdown]
# ### V2M areas = VISpm, VISam, RSPagl

# %%
VISpm = structure_tree.get_structures_by_acronym(['VISpm'])[0]
VISam = structure_tree.get_structures_by_acronym(['VISam'])[0]
RSPagl = structure_tree.get_structures_by_acronym(['RSPagl'])[0]

RSP = structure_tree.get_structures_by_acronym(['RSP'])[0]
ACA = structure_tree.get_structures_by_acronym(['ACA'])[0]
ORB = structure_tree.get_structures_by_acronym(['ORB'])[0]

cre_lines = ['Rbp4-Cre_KL100']

# %%
experiments = mcc.get_experiments(injection_structure_ids=[VISpm['id']], cre=cre_lines)
print("%d total experiments found." % len(experiments))
# Out:
# 3 total experiments found.

# %%
pd.DataFrame(experiments)
# Out:
#   gender         id injection-coordinates  \
# 0      F  294481346     [8650, 710, 7560]
# 1      F  485237081     [8590, 990, 4120]
# 2      M  523718823    [8680, 1050, 4050]
#
#                                 injection-structures  product-id strain  \
# 0  [{'id': 385, 'abbreviation': 'VISp', 'name': '...           5
# 1  [{'id': 385, 'abbreviation': 'VISp', 'name': '...          35
# 2  [{'id': 385, 'abbreviation': 'VISp', 'name': '...          36
#
#   structure-abbrev structure-color  structure-id             structure-name  \
# 0            VISpm          08858c           533  posteromedial visual area
# 1            VISpm          08858c           533  posteromedial visual area
# 2            VISpm          08858c           533  posteromedial visual area
#
#   transgenic-line
# 0  Rbp4-Cre_KL100
# 1  Rbp4-Cre_KL100
# 2  Rbp4-Cre_KL100

# %% [markdown]
# ## Getting information (e.g., density, volume of projecting signal) with Structure Signal Unionization

# %%
# return_unionizes_for_structures = None
return_unionizes_for_structures = [VISpm['id'], VISam['id'], RSPagl['id'], ACA['id']]

# %%
# https://alleninstitute.github.io/AllenSDK/allensdk.core.mouse_connectivity_cache.html#allensdk.core.mouse_connectivity_cache.MouseConnectivityCache.get_experiment_structure_unionizes
# structure_unionizes = mcc.get_experiment_structure_unionizes(120437703, is_injection=None, structure_ids=[402], include_descendants=True)
# structure_unionizes = mcc.get_structure_unionizes([e['id'] for e in experiments], is_injection=False)
structure_unionizes = mcc.get_structure_unionizes([e['id'] for e in experiments], hemisphere_ids=[1,2], structure_ids=return_unionizes_for_structures, include_descendants=True)
print("%d structure unionizes." % len(structure_unionizes))
# Out:
# 223 structure unionizes.

# %%
pd.DataFrame(structure_unionizes)
# Out:
#      hemisphere_id         id is_injection  max_voxel_density  max_voxel_x  \
# 0                1  632547324        False           0.305061         5900
# 1                1  632547937        False           0.364433         4860
# 2                1  632547405        False           0.220266         5220
# 3                1  632547676        False           0.628268         7830
# 4                2  632546842        False           0.945495         7760
# 5                1  632547408        False           0.538616         8790
# 6                1  632547346        False           0.689387         7840
# 7                2  632546860        False           0.457200         5580
# 8                2  632545854        False           1.000000         8640
# 9                1  632547760        False           0.367960         4210
# 10               2  632545327        False           0.590075         4330
# 11               2  632547044        False           0.679056         5940
# 12               1  632547648        False           0.450419         8060
# 13               2  632546689        False           0.592370         4160
# 14               2  632546941        False           0.646233         5370
# 15               1  632547310        False           0.364433         4860
# 16               2  632545291        False           0.965194         7500
# 17               2  632546896        False           0.966229         7330
# 18               1  632547672        False           0.346277         7620
# 19               2  632546517        False           0.972634         9520
# 20               2  632545228         True           1.000000         8310
# 21               2  632545092        False           0.603078         4830
# 22               1  632547335        False           0.645625         9260
# 23               1  632547240        False           0.337431         5370
# 24               1  632547427        False           0.610027         8320
# 25               2  632545283        False           0.630463         8440
# 26               2  632546747        False           0.672974         4130
# 27               1  632547201        False           0.580850         8040
# 28               2  632546693        False           0.981627         7790
# 29               1  632547317        False           0.075426         5770
# ..             ...        ...          ...                ...          ...
# 193              2  640835911        False           0.346769         8060
# 194              1  640837914        False           0.999681         8630
# 195              1  640837484         True           1.000000         9150
# 196              1  640837439        False           0.183803         5440
# 197              1  640837236        False           0.710706         7320
# 198              1  640838424        False           0.437690         4500
# 199              1  640838842        False           0.999961         8910
# 200              1  640837485        False           0.999997         9120
# 201              2  640836683        False           0.323927         8050
# 202              2  640836003        False           0.477713         8340
# 203              1  640837589        False           0.410986         5170
# 204              2  640836478        False           0.566302         9010
# 205              2  640836068        False           0.467931         8800
# 206              2  640835752        False           0.214203         8010
# 207              1  640837912         True           1.000000         8740
# 208              1  640837884        False           1.000000         8930
# 209              1  640837586        False           0.999997         9120
# 210              1  640838456        False           0.983201         8780
# 211              2  640836644        False           0.156079         4840
# 212              2  640835772        False           0.059901         4250
# 213              1  640837882         True           1.000000         8680
# 214              2  640835720        False           0.553933         8710
# 215              1  640837263        False           0.587801         8000
# 216              1  640838019        False           0.710706         7320
# 217              1  640838855        False           0.437690         4500
# 218              2  640836510        False           0.040967         5900
# 219              1  640837550        False           0.911492         9490
# 24             0.016579           4.674954            281.981537
# 25             0.189798          57.178623            301.260559
# 26             0.060991          18.015577            295.382019
# 27             0.030545           7.459267            244.203690
# 28             0.114491          62.950920            549.833130
# 29             0.000157           0.019802            126.127480
# ..                  ...                ...                   ...
# 193            0.003068           2.090954            681.638700
# 194            0.150762         313.831116           2081.637451
# 195            0.999686        7373.173492           7375.492469
# 196            0.005504           2.329294            423.223083
# 197            0.141088         152.457077           1080.579102
# 198            0.018668           9.917872            531.269104
# 199            0.070790          77.722473           1097.931641
# 200            0.083925         111.293504           1326.101549
# 201            0.004736           3.172960            669.933228
# 202            0.022030          17.450457            792.110107
# 203            0.010669           6.386307            598.607300
# 204            0.027607          17.786976            644.289368
# 205            0.012626           9.605009            760.710388
# 206            0.000933           0.532646            570.654297
# 207            0.998844        5035.322266           5041.147949
# 208            0.144452         347.765073           2407.473141
# 209            0.063213          93.789162           1483.710449
# 210            0.071674          46.702724            651.594971
# 211            0.000027           0.016156            589.733459
# 212            0.000099           0.025872            262.183228
# 213            0.997385        7239.459456           7258.438299
# 214            0.034350          23.875881            695.072571
# 215            0.101903          87.836281            861.955750
# 216            0.110388         112.255170           1016.911617
# 217            0.008048           4.312853            535.873504
# 218            0.000398           0.083208            209.025070
# 219            0.048127          46.377483            963.639526
# 220            0.000302           0.155541            515.098145
# 221            0.009086           5.274520            580.532349
# 222            0.034095          18.593130            545.338013
#
#      projection_volume  experiment_id  structure_id  sum_pixel_intensity  \
# 0             0.000138      294481346           919         2.145024e+10
# 1             0.000553      294481346            39         1.359856e+11
# 2             0.000186      294481346           810         1.368101e+10
# 3             0.007562      294481346           394         3.054192e+10
# 4             0.040557      294481346           906         3.841705e+10
# 5             0.001216      294481346           805         4.522541e+09
# 6             0.039134      294481346           894         8.157121e+10
# 7             0.000256      294481346           927         1.788212e+08
# 8             0.215296      294481346           533         3.089608e+11
# 9             0.000066      294481346           296         2.089392e+10
# 10            0.012630      294481346           296         2.491310e+10
# 11            0.021067      294481346           919         2.535923e+10
# 12            0.000268      294481346           441         2.648131e+08
# 13            0.014387      294481346           772         5.216697e+10
# 14            0.012107      294481346          1015         6.056141e+10
# 15            0.000212      294481346           935         2.341433e+10
# 16            0.017757      294481346           281         2.012788e+10
# 17            0.055233      294481346           965         5.255435e+10
# 18            0.000502      294481346           401         2.653885e+09
# 19            0.046089      294481346           671         4.946428e+10
# 20            0.022853      294481346           257         1.367249e+11
# 21            0.010223      294481346           211         2.733355e+10
# 22            0.011362      294481346           906         1.357442e+10
# 23            0.000059      294481346          1015         6.277526e+10
# 24            0.006701      294481346           774         3.119108e+10
# 25            0.003595      294481346           279         1.777835e+09
# 26            0.012218      294481346           810         1.614369e+10
# 27            0.003485      294481346          1066         7.249044e+09
# 28            0.046277      294481346           774         5.952101e+10
# 29            0.000002      294481346           927         6.088008e+07
# ..                 ...            ...           ...                  ...
# 193           0.001340      523718823           394         8.579996e+10
# 194           0.003667      523718823           501         1.157563e+10
# 195           0.009603      523718823           894         5.782277e+10
# %% [markdown]
# ### Selecting dense unionizes from this

# %%
MIN_DENSITY = 0.5
MIN_VOLUME = 0.1

filtered_unionizes = structure_unionizes[structure_unionizes.projection_density > MIN_DENSITY]
filtered_unionizes = filtered_unionizes[filtered_unionizes.volume > MIN_VOLUME]

# %%
large_structures = pd.DataFrame(structure_tree.nodes(filtered_unionizes.structure_id))
print("%d large and dense unionizes, %d structures" % ( len(filtered_unionizes), len(large_structures) ))
# print(large_structures.name)
# Out:
# 57 large and dense unionizes, 57 structures

# %% [markdown]
# ## Projection Matrix

# %%
def get_structure_name_from_id(s_id):
    s = structure_tree.get_structures_by_id([s_id])[0]
    return s['name']

# hemisphere_id	ID of the hemisphere (1 = left, 2 = right, 3 = both)
def select_highest_projections(p_matrix, number_to_select=10, hemisphere='both', change_labels=False):
    if hemisphere=='left': hemisphere = 1
    elif hemisphere=='right': hemisphere = 2
    elif hemisphere=='both': hemisphere = 3
    matrix = p_matrix['matrix']
    exp_ids = p_matrix['rows']
    area_info = p_matrix['columns']
    
    sum_along_exps = np.sum(matrix, axis=0)
    highest_inds = np.argsort(sum_along_exps)[-number_to_select:]
    highest_inds = highest_inds[::-1]
    
    out_matrix = {}
    out_matrix['matrix'] = matrix[:,highest_inds]
    out_matrix['columns'] = []
    out_matrix['rows'] = exp_ids
    for i in highest_inds: 
        out_matrix['columns'].append(area_info[i])
        if change_labels: out_matrix['columns'][-1]['label'] = get_structure_name_from_id(out_matrix['columns'][-1]['structure_id'])
    
    return out_matrix

def get_projection_target_areas_from_set(set_id):
    return list(pd.DataFrame(structure_tree.get_structures_by_set_id([set_id])).id)

# %%
experiment_ids = [e['id'] for e in experiments]
# children_areas = structure_tree.child_ids([AREA_ID])[0]
# projection_areas = children_areas
# projection_areas = list(coarse_set_df.id)
projection_areas = get_projection_target_areas_from_set(3) # coarse
# projection_areas = get_projection_target_areas_from_set(167587189) # identical to connectivity.brain-map.org

proj_matrix = mcc.get_projection_matrix(experiment_ids = experiment_ids, 
                               projection_structure_ids = projection_areas,
                               parameter = 'projection_density')

# proj_matrix

# %%
proj_matrix = select_highest_projections(proj_matrix, number_to_select=10, hemisphere='both', change_labels=False)

# %%
row_labels = proj_matrix['rows'] # these are just experiment ids
column_labels = [ c['label'] for c in proj_matrix['columns'] ] 
matrix = proj_matrix['matrix']

fig, ax = plt.subplots(figsize=(15,15), facecolor='white')
heatmap = ax.pcolor(matrix, cmap=plt.cm.afmhot)

# put the major ticks at the middle of each cell
ax.set_xticks(np.arange(matrix.shape[1])+0.5, minor=False)
ax.set_yticks(np.arange(matrix.shape[0])+0.5, minor=False)

ax.set_xlim([0, matrix.shape[1]])
ax.set_ylim([0, matrix.shape[0]])          

# want a more natural, table-like display
ax.invert_yaxis()
# ax.xaxis.tick_top()

ax.set_xticklabels(column_labels, minor=False)
ax.set_yticklabels(row_labels, minor=False)

plt.xlabel('Areas')
plt.ylabel('Experiment IDs')
# Out:
# Text(0, 0.5, 'Experiment IDs')

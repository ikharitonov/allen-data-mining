# %% [markdown]
# # Data Mining Example with AllenSDK
# From https://allensdk.readthedocs.io/en/latest/_static/examples/nb/mouse_connectivity.html

# %%
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache
from allensdk.api.queries.ontologies_api import OntologiesApi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
mcc = MouseConnectivityCache()

# %%
structure_tree = mcc.get_structure_tree()

# %%
oapi = OntologiesApi()
structure_set_ids = structure_tree.get_structure_sets()
pd.DataFrame(oapi.get_structure_sets(structure_set_ids))
# Out:
#                                           description         id  \
# 0             List of structures in Isocortex layer 5  667481446
# 1            List of structures in Isocortex layer 6b  667481450
# 2                Summary structures of the cerebellum  688152368
# 3      List of structures for ABA Differential Search         12
# 4   List of valid structures for projection target...  184527634
# 5   Structures whose surfaces are represented by a...  691663206
# 6                  Summary structures of the midbrain  688152365
# 7                   Summary structures of the medulla  688152367
# 8                  Summary structures of the striatum  688152361
# 9   Structures representing subdivisions of the mo...  687527945
# 10    Summary structures of the hippocampal formation  688152359
# 11  List of visual cortex structures targeted for ...  514166994
# 12          Summary structures of the olfactory areas  688152358
# 13  Curated list of non-overlapping substructures ...  167587189
# 14            List of structures in Isocortex layer 4  667481445
# 15  Structures representing the major divisions of...  687527670
# 16                 Summary structures of the pallidum  688152362
# 17  List of Primary injection structures for BDA/A...  114512892
# 18  List of primary AND secondary injection struct...  112905813
# 19   List of structures for ABA Fine Structure Search         10
# 20  List of primary AND secondary injection struct...  112905828
# 21           List of structures in Isocortex layer 6a  667481449
# 22  List of structures representing a areal level ...          3
# 23            List of structures in Isocortex layer 1  667481440
# 24             Summary structures of the hypothalamus  688152364
# 25          List of structures in Isocortex layer 2/3  667481441
# 26                 All mouse visual areas with layers  396673091
# 27        Summary structures of the cortical subplate  688152360
# 28                 Summary structures of the thalamus  688152363
# 29  List of structures representing a coarse level...          2
# 30                Summary structures of the isocortex  688152357
# 31  List of Primary injection structures for Proje...  114512891
# 32                     Summary structures of the pons  688152366
#
#                                                  name
# 0                                   Isocortex layer 5
# 1                                  Isocortex layer 6b
# 2                                          Cerebellum
# 3                           ABA - Differential Search
# 4                  Mouse Connectivity - Target Search
# 5                      Mouse Brain - Has Surface Mesh
# 6                                            Midbrain
# 7                                             Medulla
# 8                                            Striatum
# 9                        Mouse Connectivity - Summary
# 10                              Hippocampal Formation
# 11     Allen Brain Observatory targeted structure set
# 12                                    Olfactory Areas
# 13                         Brain – Summary Structures
# 14                                  Isocortex layer 4
# 15                            Brain - Major Divisions
# 16                                           Pallidum
# 17  Mouse Connectivity - BDA/AAV Primary Injection...
# 18  Mouse Connectivity - BDA/AAV All Injection Str...
# 19                        ABA - Fine Structure Search
# 20  Mouse Connectivity - Projection All Injection ...
# 21                                 Isocortex layer 6a
# 22                                      Mouse - Areas
# 23                                  Isocortex layer 1
# 24                                       Hypothalamus
# 25                                Isocortex layer 2/3
# 26                      Mouse Cell Types - Structures
# 27                                  Cortical Subplate
# 28                                           Thalamus
# 29                                     Mouse - Coarse
# 30                                          Isocortex
# 31  Mouse Connectivity - Projection Primary Inject...
# 32                                               Pons

# %% [markdown]
# ## Visual Areas List

# %%
# SET_ID = 396673091
SET_ID = 3

coarse_set_list = structure_tree.get_structures_by_set_id([SET_ID])
# coarse_set = [{'name': area['name'], 'id': area['id']} for area in coarse_set_list]
coarse_set_df = pd.DataFrame(coarse_set_list)
# print(coarse_set)
coarse_set_df
# Out:
#    acronym  graph_id  graph_order     id  \
# 0      FRP         1            6    184
# 1       MO         1           12    500
# 2       SS         1           30    453
# 3       GU         1          107   1057
# 4     VISC         1          114    677
# 5      AUD         1          121    247
# 6      VIS         1          157    669
# 7      ACA         1          220     31
# 8       PL         1          238    972
# 9      ILA         1          245     44
# 10     ORB         1          252    714
# 11      AI         1          278     95
# 12     RSP         1          297    254
# 13    PTLp         1          339     22
# 14     TEa         1          360    541
# 15    PERI         1          367    922
# 16     ECT         1          373    895
# 17     OLF         1          379    698
# 18      CA         1          456    375
# 19      DG         1          473    726
# 20      FC         1          490    982
# 21      IG         1          491     19
# 22     RHP         1          492    822
# 23   CTXsp         1          555    703
# 24    STRd         1          572    485
# 25    STRv         1          574    493
# 26     LSX         1          585    275
# 27    sAMY         1          592    278
# 28    PALd         1          609    818
# 29    PALv         1          612    835
# 30    PALm         1          615    826
# 31    PALc         1          620    809
# 32   DORsm         1          642    864
# 33   DORpm         1          666    856
# 34     PVZ         1          716    157
# 35     PVR         1          734    141
# 36     MEZ         1          756    467
# 37      LZ         1          793    290
# 38      ME         1          805  10671
# 39   MBsen         1          807    339
# 40   MBmot         1          821    323
# 41   MBsta         1          865    348
# 42   P-sen         1          884   1132
# 43   P-mot         1          906    987
# 44   P-sat         1          924   1117
# 45  MY-sen         1          936    386
# 46  MY-mot         1          964    370
# 47  MY-sat         1         1010    379
# 48    VERM         1         1019    645
# 49     HEM         1         1066   1073
# 50     CBN         1         1096    519
#
#                                               name      rgb_triplet  \
# 0                    Frontal pole, cerebral cortex    [38, 143, 69]
# 1                                Somatomotor areas    [31, 157, 90]
# 2                              Somatosensory areas   [24, 128, 100]
# 3                                  Gustatory areas    [0, 156, 117]
# 4                                    Visceral area   [17, 173, 131]
# 5                                   Auditory areas    [1, 147, 153]
# 6                                     Visual areas    [8, 133, 140]
# 7                          Anterior cingulate area   [64, 166, 102]
# 8                                   Prelimbic area    [47, 168, 80]
# 9                                 Infralimbic area    [89, 179, 99]
# 10                                    Orbital area    [36, 138, 94]
# 11                          Agranular insular area   [33, 152, 102]
# 12                              Retrosplenial area   [26, 166, 152]
# 13            Posterior parietal association areas    [0, 159, 172]
# 14                      Temporal association areas   [21, 176, 179]
# 15                                 Perirhinal area   [14, 150, 132]
# 16                                 Ectorhinal area   [13, 159, 145]
# 17                                 Olfactory areas  [154, 210, 189]
# 18                                    Ammon's horn   [126, 208, 75]
# 19                                   Dentate gyrus   [126, 208, 75]
# 20                                Fasciola cinerea   [126, 208, 75]
# 21                                Induseum griseum   [126, 208, 75]
# 22                         Retrohippocampal region    [50, 184, 37]
# 23                               Cortical subplate  [138, 218, 135]
# 24                          Striatum dorsal region  [152, 214, 249]
# 25                         Striatum ventral region  [128, 205, 248]
# 26                          Lateral septal complex  [144, 203, 237]
# 27                  Striatum-like amygdalar nuclei  [128, 192, 226]
# 28                         Pallidum, dorsal region  [133, 153, 204]
# 29                        Pallidum, ventral region  [162, 177, 216]
# 30                         Pallidum, medial region  [150, 167, 211]
# 31                         Pallidum, caudal region  [179, 192, 223]
# 32          Thalamus, sensory-motor cortex related  [255, 128, 132]
# 33  Thalamus, polymodal association cortex related  [255, 144, 159]
# 34                            Periventricular zone    [255, 93, 80]
# 35                          Periventricular region    [255, 85, 71]
# 36                        Hypothalamic medial zone    [255, 76, 62]
# 37                       Hypothalamic lateral zone    [242, 72, 59]
# 38                                 Median eminence    [242, 72, 59]
# 39                       Midbrain, sensory related  [255, 122, 255]
# 40                         Midbrain, motor related  [255, 144, 255]
# 41              Midbrain, behavioral state related  [255, 144, 255]
# 42                           Pons, sensory related  [255, 174, 111]
# 43                             Pons, motor related  [255, 186, 134]
# 44                  Pons, behavioral state related  [255, 195, 149]
# 45                        Medulla, sensory related  [255, 165, 210]
# 46                          Medulla, motor related  [255, 179, 217]
# 47               Medulla, behavioral state related  [255, 198, 226]
# 48                                  Vermal regions  [255, 252, 145]
# 49                             Hemispheric regions  [255, 252, 145]
# 50                               Cerebellar nuclei  [240, 240, 128]
#
#                            structure_id_path  \
# 0          [997, 8, 567, 688, 695, 315, 184]
# 1          [997, 8, 567, 688, 695, 315, 500]
# 2          [997, 8, 567, 688, 695, 315, 453]
# 3         [997, 8, 567, 688, 695, 315, 1057]
# 4          [997, 8, 567, 688, 695, 315, 677]
# 5          [997, 8, 567, 688, 695, 315, 247]
# 6          [997, 8, 567, 688, 695, 315, 669]
# 7           [997, 8, 567, 688, 695, 315, 31]
# 8          [997, 8, 567, 688, 695, 315, 972]
# 9           [997, 8, 567, 688, 695, 315, 44]
# 10         [997, 8, 567, 688, 695, 315, 714]
# 11          [997, 8, 567, 688, 695, 315, 95]
# 12         [997, 8, 567, 688, 695, 315, 254]
# 13          [997, 8, 567, 688, 695, 315, 22]
# 14         [997, 8, 567, 688, 695, 315, 541]
# 15         [997, 8, 567, 688, 695, 315, 922]
# 16         [997, 8, 567, 688, 695, 315, 895]
# 17              [997, 8, 567, 688, 695, 698]
# 18  [997, 8, 567, 688, 695, 1089, 1080, 375]
# 19  [997, 8, 567, 688, 695, 1089, 1080, 726]
# 20  [997, 8, 567, 688, 695, 1089, 1080, 982]
# 21   [997, 8, 567, 688, 695, 1089, 1080, 19]
# 22        [997, 8, 567, 688, 695, 1089, 822]
# 23                   [997, 8, 567, 688, 703]
# 24              [997, 8, 567, 623, 477, 485]
# 25              [997, 8, 567, 623, 477, 493]
# 26              [997, 8, 567, 623, 477, 275]
# 31  [3, 112905828, 691663206, 12, 184527634, 11451...
# 32  [3, 112905828, 691663206, 12, 184527634, 11290...
# 33  [3, 112905828, 691663206, 12, 184527634, 11290...
# 34  [3, 112905828, 691663206, 12, 184527634, 11451...
# 35  [3, 112905828, 691663206, 12, 184527634, 11451...
# 36  [3, 112905828, 691663206, 12, 184527634, 11451...
# 37  [3, 112905828, 691663206, 12, 184527634, 11290...
# 38  [3, 112905828, 691663206, 12, 688152364, 18452...
# 39  [3, 112905828, 691663206, 12, 184527634, 11290...
# 40  [3, 112905828, 691663206, 12, 184527634, 11290...
# 41  [3, 112905828, 691663206, 12, 184527634, 11290...
# 42  [3, 112905828, 691663206, 12, 184527634, 11290...
# 43  [3, 112905828, 691663206, 12, 184527634, 11290...
# 44  [3, 112905828, 691663206, 12, 184527634, 11451...
# 45  [3, 112905828, 691663206, 12, 184527634, 11451...
# 46  [3, 112905828, 691663206, 12, 184527634, 11290...
# 47  [3, 112905828, 691663206, 12, 184527634, 11451...
# 48  [3, 112905828, 691663206, 12, 184527634, 11290...
# 49  [3, 112905828, 691663206, 12, 184527634, 11451...
# 50  [3, 112905828, 691663206, 10, 12, 184527634, 1...

# %% [markdown]
# ### Getting child nodes of an area

# %%
AREA_GROUP_ID = 254

children = structure_tree.children([AREA_GROUP_ID])[0]
pd.DataFrame(children)
# Out:
#   acronym  graph_id  graph_order   id  \
# 0  RSPagl         1          298  894
# 1    RSPd         1          325  879
# 2    RSPv         1          332  886
#
#                                          name     rgb_triplet  \
# 0  Retrosplenial area, lateral agranular part  [26, 166, 152]
# 1             Retrosplenial area, dorsal part  [26, 166, 152]
# 2            Retrosplenial area, ventral part  [26, 166, 152]
#
#                         structure_id_path  \
# 0  [997, 8, 567, 688, 695, 315, 254, 894]
# 1  [997, 8, 567, 688, 695, 315, 254, 879]
# 2  [997, 8, 567, 688, 695, 315, 254, 886]
#
#                                    structure_set_ids
# 0  [112905828, 688152357, 691663206, 687527945, 1...
# 1  [112905828, 688152357, 691663206, 687527945, 1...
# 2  [112905828, 688152357, 691663206, 687527945, 1...

# %% [markdown]
# ## Getting list of experiements with injection in visual areas

# %%
# AREA_ID = 402 # Anterolateral visual area
# AREA_ID = 254 # RSP
# AREA_ID = 31 # ACA
AREA_ID = 714 # ORB

# injection_area = structure_tree.get_structures_by_id([AREA_ID])
experiments = mcc.get_experiments(injection_structure_ids=[AREA_ID], cre=False)

print("%d total experiments found." % len(experiments))
# Out:
# 7 total experiments found.

# %%
pd.DataFrame(experiments)
# Out:
#   gender         id injection-coordinates  \
# 0      M  180709230    [3010, 4370, 7970]
# 1      M  112306316    [2790, 2980, 7050]
# 2      M  170721670    [2290, 3270, 7440]
# 3      M  126860974    [2350, 3590, 6020]
# 4      M  112423392    [2930, 2920, 6610]
# 5      M  180673746    [2090, 3180, 7380]
# 6      M  158435116    [2690, 3940, 6590]
#
#                                 injection-structures  product-id    strain  \
# 0  [{'id': 104, 'abbreviation': 'AId', 'name': 'A...           5  C57BL/6J
# 1  [{'id': 184, 'abbreviation': 'FRP', 'name': 'F...           5  C57BL/6J
# 2  [{'id': 151, 'abbreviation': 'AOB', 'name': 'A...           5  C57BL/6J
# 3  [{'id': 731, 'abbreviation': 'ORBm', 'name': '...           5  C57BL/6J
# 4  [{'id': 184, 'abbreviation': 'FRP', 'name': 'F...           5  C57BL/6J
# 5  [{'id': 184, 'abbreviation': 'FRP', 'name': 'F...           5  C57BL/6J
# 6  [{'id': 723, 'abbreviation': 'ORBl', 'name': '...           5  C57BL/6J
#
#   structure-abbrev structure-color  structure-id  \
# 0             ORBl          248a5e           723
# 1             ORBl          248a5e           723
# 2             ORBl          248a5e           723
# 3             ORBm          248a5e           731
# 4            ORBvl          248a5e           746
# 5             ORBl          248a5e           723
# 6            ORBvl          248a5e           746
#
#                      structure-name transgenic-line
# 0        Orbital area, lateral part
# 1        Orbital area, lateral part
# 2        Orbital area, lateral part
# 3         Orbital area, medial part
# 4  Orbital area, ventrolateral part
# 5        Orbital area, lateral part
# 6  Orbital area, ventrolateral part

# %% [markdown]
# ## Getting information (e.g., density, volume of projecting signal) with Structure Signal Unionization

# %%
# https://alleninstitute.github.io/AllenSDK/allensdk.core.mouse_connectivity_cache.html#allensdk.core.mouse_connectivity_cache.MouseConnectivityCache.get_experiment_structure_unionizes
# structure_unionizes = mcc.get_experiment_structure_unionizes(120437703, is_injection=None, structure_ids=[402], include_descendants=True)
structure_unionizes = mcc.get_structure_unionizes([e['id'] for e in experiments], is_injection=False)
print("%d structure unionizes." % len(structure_unionizes))
# Out:
# 17640 structure unionizes.

# %%
pd.DataFrame(structure_unionizes)
# Out:
#        hemisphere_id         id is_injection  max_voxel_density  max_voxel_x  \
# 0                  3  630418198        False           0.358742         7970
# 1                  3  630418998        False           0.391097         8310
# 2                  2  630416242        False           0.157474        12890
# 3                  2  630415456        False           0.432260        11680
# 4                  2  630416221        False           0.197515         6640
# 5                  3  630418050        False           0.041686         8480
# 6                  2  630415944        False           0.650050         5850
# 7                  2  630415346        False           0.000000            0
# 8                  3  630419944        False           0.849486         8780
# 9                  2  630414743        False           0.217529         9730
# 10                 3  630418416        False           0.321169         9380
# 11                 1  630417427        False           0.495446         4900
# 12                 3  630419120        False           0.458430         7770
# 13                 2  630416144        False           0.631030         9570
# 14                 2  630416463        False           0.674541         7400
# 15                 3  630419865        False           0.560225         6630
# 16                 2  630416041        False           0.273874         6450
# 17                 2  630416055        False           1.000000         3460
# 18                 1  630416756        False           0.272194         7550
# 19                 2  630414801        False           0.550561         7960
# 20                 2  630415444        False           0.486644         6410
# 21                 3  630418025        False           0.705549         7390
# 22                 2  630415436        False           0.585064         7070
# 23                 3  630419107        False           0.215691         7330
# 24                 2  630415963        False           0.375424         8540
# 25                 1  630417939        False           0.016062         5820
# 26                 1  630416734        False           0.532670         4250
# 27                 3  630420075        False           0.087073         7480
# 17613  2.607644e+09                    2.331688e+09           4.179907e+06
# 17614  4.579488e+08                    2.808963e+08           4.226348e+05
# 17615  1.212143e+10                    2.340432e+11           3.077087e+08
# 17616  3.623400e+07                    9.632274e+05           1.589170e+03
# 17617  8.551269e+08                    0.000000e+00           0.000000e+00
# 17618  1.118169e+08                    1.435768e+08           2.445307e+05
# 17619  6.966000e+07                    5.445942e+06           8.374560e+03
# 17620  6.612570e+07                    9.091595e+07           1.515978e+05
# 17621  4.719438e+08                    6.676501e+08           1.184208e+06
# 17622  8.468613e+08                    1.536120e+08           2.506140e+05
# 17623  2.242080e+07                    1.110533e+07           2.275388e+04
# 17624  8.685414e+08                    4.237918e+08           1.035363e+06
# 17625  6.806340e+07                    1.455718e+07           3.231506e+04
# 17626  6.033159e+08                    1.703681e+06           2.705509e+03
# 17627  8.894160e+07                    2.639730e+06           3.731445e+03
# 17628  7.230600e+07                    1.081872e+08           1.697807e+05
# 17629  2.406402e+08                    3.895045e+08           6.723649e+05
# 17630  5.070960e+07                    1.385904e+07           2.782040e+04
# 17631  8.784630e+07                    0.000000e+00           0.000000e+00
# 17632  8.380800e+06                    0.000000e+00           0.000000e+00
# 17633  2.995533e+08                    5.957614e+08           1.854899e+06
# 17634  1.698750e+08                    0.000000e+00           0.000000e+00
# 17635  1.631970e+08                    5.284918e+07           8.355991e+04
# 17636  1.486512e+09                    4.282400e+08           8.178262e+05
# 17637  1.744110e+08                    2.134497e+08           4.791205e+05
# 17638  5.108100e+09                    4.928090e+08           8.864207e+05
# 17639  1.472670e+07                    1.091593e+07           2.466442e+04
#
#           volume
# 0       0.203453
# 1       1.121975
# 2       1.208083
# 3       4.373129
# 4       0.103596
# 5       0.228264
# 6       0.412338
# 7       0.113089
# 8       1.063963
# 9       0.609724
# 10      0.108254
# 11      0.414858
# 12      0.595500
# 13      0.115422
# 14      0.793339
# 15      0.369415
# 16      0.925411
# 17     23.679522
# 18      0.132749
# 19      0.590314
# 20      2.077916
# 21      0.194492
# 22      0.006866
# 23      0.352831
# 24      0.050920
# 25      0.088814
# 26      1.869503
# 27      0.068002
# 28      7.799233
# 29      0.037127
# ...          ...
# 17610   0.815775
# 17611   0.024531
# 17612   0.027633
# 17613   3.194364
# 17614   0.560987
# 17615  14.848757
# 17616   0.044387
# 17617   1.047530
# 17618   0.136976
# 17619   0.085334
# 17620   0.081004
# 17621   0.578131
# 17622   1.037405
# 17623   0.027465
# 17624   1.063963
# 17625   0.083378
# 17626   0.739062
# 17627   0.108953
# 17628   0.088575
# 17629   0.294784
# 17630   0.062119
# 17631   0.107612
# 17632   0.010266
# 17633   0.366953
# 17634   0.208097
# 17635   0.199916
# 17636   1.820977
# 17637   0.213653
# 17638   6.257423
# 17639   0.018040
#
# [17640 rows x 19 columns]

# %% [markdown]
# Reference for unionization table columns: https://alleninstitute.github.io/AllenSDK/unionizes.html

# %% [markdown]
# ### Selecting dense unionizes from this

# %%
MIN_DENSITY = 0.5
MIN_VOLUME = 0.1

filtered_unionizes = structure_unionizes[structure_unionizes.projection_density > MIN_DENSITY]
filtered_unionizes = filtered_unionizes[filtered_unionizes.volume > MIN_VOLUME]

# %%
large_structures = pd.DataFrame(structure_tree.nodes(filtered_unionizes.structure_id))
print("%d large and dense unionizes, %d structures" % ( len(filtered_unionizes), len(large_structures) ))
# print(large_structures.name)
# Out:
# 57 large and dense unionizes, 57 structures

# %% [markdown]
# ## Projection Matrix

# %%
def get_structure_name_from_id(s_id):
    s = structure_tree.get_structures_by_id([s_id])[0]
    return s['name']

# hemisphere_id	ID of the hemisphere (1 = left, 2 = right, 3 = both)
def select_highest_projections(p_matrix, number_to_select=10, hemisphere='both', change_labels=False):
    if hemisphere=='left': hemisphere = 1
    elif hemisphere=='right': hemisphere = 2
    elif hemisphere=='both': hemisphere = 3
    matrix = p_matrix['matrix']
    exp_ids = p_matrix['rows']
    area_info = p_matrix['columns']
    
    sum_along_exps = np.sum(matrix, axis=0)
    highest_inds = np.argsort(sum_along_exps)[-number_to_select:]
    highest_inds = highest_inds[::-1]
    
    out_matrix = {}
    out_matrix['matrix'] = matrix[:,highest_inds]
    out_matrix['columns'] = []
    out_matrix['rows'] = exp_ids
    for i in highest_inds: 
        out_matrix['columns'].append(area_info[i])
        if change_labels: out_matrix['columns'][-1]['label'] = get_structure_name_from_id(out_matrix['columns'][-1]['structure_id'])
    
    return out_matrix

def get_projection_target_areas_from_set(set_id):
    return list(pd.DataFrame(structure_tree.get_structures_by_set_id([set_id])).id)

# %%
experiment_ids = [e['id'] for e in experiments]
# children_areas = structure_tree.child_ids([AREA_ID])[0]
# projection_areas = children_areas
# projection_areas = list(coarse_set_df.id)
projection_areas = get_projection_target_areas_from_set(3) # coarse
# projection_areas = get_projection_target_areas_from_set(167587189) # identical to connectivity.brain-map.org

proj_matrix = mcc.get_projection_matrix(experiment_ids = experiment_ids, 
                               projection_structure_ids = projection_areas,
                               parameter = 'projection_density')

# proj_matrix

# %%
proj_matrix = select_highest_projections(proj_matrix, number_to_select=10, hemisphere='both', change_labels=False)

# %%
row_labels = proj_matrix['rows'] # these are just experiment ids
column_labels = [ c['label'] for c in proj_matrix['columns'] ] 
matrix = proj_matrix['matrix']

fig, ax = plt.subplots(figsize=(15,15), facecolor='white')
heatmap = ax.pcolor(matrix, cmap=plt.cm.afmhot)

# put the major ticks at the middle of each cell
ax.set_xticks(np.arange(matrix.shape[1])+0.5, minor=False)
ax.set_yticks(np.arange(matrix.shape[0])+0.5, minor=False)

ax.set_xlim([0, matrix.shape[1]])
ax.set_ylim([0, matrix.shape[0]])          

# want a more natural, table-like display
ax.invert_yaxis()
# ax.xaxis.tick_top()

ax.set_xticklabels(column_labels, minor=False)
ax.set_yticklabels(row_labels, minor=False)

plt.xlabel('Areas')
plt.ylabel('Experiment IDs')
# Out:
# Text(0, 0.5, 'Experiment IDs')
